# %%
# %%writefile voc.yaml
# dataset_params:
#   # Kaggle input paths are usually read-only
#   # Ensure you add the 'PASCAL VOC 2012' dataset to your notebook
#   im_train_path: '/kaggle/input/pascal-voc-2012-dataset/VOC2012_train_val/VOC2012_train_val/JPEGImages'
#   ann_train_path: '/kaggle/input/pascal-voc-2012-dataset/VOC2012_train_val/VOC2012_train_val/Annotations'
#   im_test_path: '/kaggle/input/pascal-voc-2012-dataset/VOC2012_test/VOC2012_test/JPEGImages' # Using same for demo if test set isn't separate
#   ann_test_path: '/kaggle/input/pascal-voc-2012-dataset/VOC2012_test/VOC2012_test/Annotations'
#   num_classes : 21
#
# model_params:
#   im_channels : 3
#   aspect_ratios: [0.5, 1, 2]
#   scales: [128, 256, 512]
#   min_im_size : 600
#   max_im_size : 1000
#   backbone_out_channels : 512
#   fc_inner_dim : 1024
#   rpn_bg_threshold : 0.3
#   rpn_fg_threshold : 0.7
#   rpn_nms_threshold : 0.7
#   rpn_train_prenms_topk : 12000
#   rpn_test_prenms_topk : 6000
#   rpn_train_topk : 2000
#   rpn_test_topk : 300
#   rpn_batch_size : 256
#   rpn_pos_fraction : 0.5
#   roi_iou_threshold : 0.5
#   roi_low_bg_iou : 0.0
#   roi_pool_size : 7
#   roi_nms_threshold : 0.3
#   roi_topk_detections : 100
#   roi_score_threshold : 0.05
#   roi_batch_size : 128
#   roi_pos_fraction : 0.25
#
# train_params:
#   task_name: 'voc_scratch_kaggle'
#   seed : 1111
#   acc_steps : 4 # Keep high for stability
#   num_epochs: 50
#   lr_steps : [35, 45]
#   lr: 0.0001 # Safer for scratch training
#   ckpt_name: 'faster_rcnn_voc_scratch.pth'
# Out:
# Overwriting voc.yaml

# %%
# %%writefile faster_rcnn.py
import torch
import torch.nn as nn
import torchvision
import math

def get_iou(boxes1, boxes2):
    r"""
    IOU between two sets of boxes
    :param boxes1: (Tensor of shape N x 4)
    :param boxes2: (Tensor of shape M x 4)
    :return: IOU matrix of shape N x M
    """
    # Area of boxes (x2-x1)*(y2-y1)
    area1 = (boxes1[:, 2] - boxes1[:, 0]) * (boxes1[:, 3] - boxes1[:, 1])  # (N,)
    area2 = (boxes2[:, 2] - boxes2[:, 0]) * (boxes2[:, 3] - boxes2[:, 1])  # (M,)

    # Get top left x1,y1 coordinate
    x_left = torch.max(boxes1[:, None, 0], boxes2[:, 0])  # (N, M)
    y_top = torch.max(boxes1[:, None, 1], boxes2[:, 1])  # (N, M)

    # Get bottom right x2,y2 coordinate
    x_right = torch.min(boxes1[:, None, 2], boxes2[:, 2])  # (N, M)
    y_bottom = torch.min(boxes1[:, None, 3], boxes2[:, 3])  # (N, M)

    intersection_area = (x_right - x_left).clamp(min=0) * (y_bottom - y_top).clamp(min=0)  # (N, M)
    union = area1[:, None] + area2 - intersection_area  # (N, M)
    iou = intersection_area / union  # (N, M)
    return iou


def boxes_to_transformation_targets(ground_truth_boxes, anchors_or_proposals):
    r"""
    Given all anchor boxes or proposals in image and their respective
    ground truth assignments, we use the x1,y1,x2,y2 coordinates of them
    to get tx,ty,tw,th transformation targets for all anchor boxes or proposals
    """
    # Get center_x,center_y,w,h from x1,y1,x2,y2 for anchors
    widths = anchors_or_proposals[:, 2] - anchors_or_proposals[:, 0]
    heights = anchors_or_proposals[:, 3] - anchors_or_proposals[:, 1]
    center_x = anchors_or_proposals[:, 0] + 0.5 * widths
    center_y = anchors_or_proposals[:, 1] + 0.5 * heights

    # Get center_x,center_y,w,h from x1,y1,x2,y2 for gt boxes
    gt_widths = ground_truth_boxes[:, 2] - ground_truth_boxes[:, 0]
    gt_heights = ground_truth_boxes[:, 3] - ground_truth_boxes[:, 1]
    gt_center_x = ground_truth_boxes[:, 0] + 0.5 * gt_widths
    gt_center_y = ground_truth_boxes[:, 1] + 0.5 * gt_heights

    targets_dx = (gt_center_x - center_x) / widths
    targets_dy = (gt_center_y - center_y) / heights
    targets_dw = torch.log(gt_widths / widths)
    targets_dh = torch.log(gt_heights / heights)
    regression_targets = torch.stack((targets_dx, targets_dy, targets_dw, targets_dh), dim=1)
    return regression_targets


def apply_regression_pred_to_anchors_or_proposals(box_transform_pred, anchors_or_proposals):
    r"""
    Given the transformation parameter predictions for all
    input anchors or proposals, transform them accordingly
    to generate predicted proposals or predicted boxes
    """
    box_transform_pred = box_transform_pred.reshape(
        box_transform_pred.size(0), -1, 4)

    # Get cx, cy, w, h from x1,y1,x2,y2
    w = anchors_or_proposals[:, 2] - anchors_or_proposals[:, 0]
    h = anchors_or_proposals[:, 3] - anchors_or_proposals[:, 1]
    center_x = anchors_or_proposals[:, 0] + 0.5 * w
    center_y = anchors_or_proposals[:, 1] + 0.5 * h

    dx = box_transform_pred[..., 0]
    dy = box_transform_pred[..., 1]
    dw = box_transform_pred[..., 2]
    dh = box_transform_pred[..., 3]

    # Prevent sending too large values into torch.exp()
    dw = torch.clamp(dw, max=math.log(1000.0 / 16))
    dh = torch.clamp(dh, max=math.log(1000.0 / 16))

    pred_center_x = dx * w[:, None] + center_x[:, None]
    pred_center_y = dy * h[:, None] + center_y[:, None]
    pred_w = torch.exp(dw) * w[:, None]
    pred_h = torch.exp(dh) * h[:, None]

    pred_box_x1 = pred_center_x - 0.5 * pred_w
    pred_box_y1 = pred_center_y - 0.5 * pred_h
    pred_box_x2 = pred_center_x + 0.5 * pred_w
    pred_box_y2 = pred_center_y + 0.5 * pred_h

    pred_boxes = torch.stack((
        pred_box_x1,
        pred_box_y1,
        pred_box_x2,
        pred_box_y2),
        dim=2)
    return pred_boxes


def sample_positive_negative(labels, positive_count, total_count):
    # Sample positive and negative proposals
    positive = torch.where(labels >= 1)[0]
    negative = torch.where(labels == 0)[0]
    num_pos = positive_count
    num_pos = min(positive.numel(), num_pos)
    num_neg = total_count - num_pos
    num_neg = min(negative.numel(), num_neg)
    perm_positive_idxs = torch.randperm(positive.numel(),
                                        device=positive.device)[:num_pos]
    perm_negative_idxs = torch.randperm(negative.numel(),
                                        device=negative.device)[:num_neg]
    pos_idxs = positive[perm_positive_idxs]
    neg_idxs = negative[perm_negative_idxs]
    sampled_pos_idx_mask = torch.zeros_like(labels, dtype=torch.bool)
    sampled_neg_idx_mask = torch.zeros_like(labels, dtype=torch.bool)
    sampled_pos_idx_mask[pos_idxs] = True
    sampled_neg_idx_mask[neg_idxs] = True
    return sampled_neg_idx_mask, sampled_pos_idx_mask


def clamp_boxes_to_image_boundary(boxes, image_shape):
    boxes_x1 = boxes[..., 0]
    boxes_y1 = boxes[..., 1]
    boxes_x2 = boxes[..., 2]
    boxes_y2 = boxes[..., 3]
    height, width = image_shape[-2:]
    boxes_x1 = boxes_x1.clamp(min=0, max=width)
    boxes_x2 = boxes_x2.clamp(min=0, max=width)
    boxes_y1 = boxes_y1.clamp(min=0, max=height)
    boxes_y2 = boxes_y2.clamp(min=0, max=height)
    boxes = torch.cat((
        boxes_x1[..., None],
        boxes_y1[..., None],
        boxes_x2[..., None],
        boxes_y2[..., None]),
        dim=-1)
    return boxes


def transform_boxes_to_original_size(boxes, new_size, original_size):
    r"""
    Boxes are for resized image (min_size=600, max_size=1000).
    This method converts the boxes to whatever dimensions
    the image was before resizing
    """
    ratios = [
        torch.tensor(s_orig, dtype=torch.float32, device=boxes.device)
        / torch.tensor(s, dtype=torch.float32, device=boxes.device)
        for s, s_orig in zip(new_size, original_size)
    ]
    ratio_height, ratio_width = ratios
    xmin, ymin, xmax, ymax = boxes.unbind(1)
    xmin = xmin * ratio_width
    xmax = xmax * ratio_width
    ymin = ymin * ratio_height
    ymax = ymax * ratio_height
    return torch.stack((xmin, ymin, xmax, ymax), dim=1)


class RegionProposalNetwork(nn.Module):
    r"""
    RPN with following layers on the feature map
        1. 3x3 conv layer followed by Relu
        2. 1x1 classification conv with num_anchors output channels
        3. 1x1 classification conv with 4 x num_anchors output channels
    """

    def __init__(self, in_channels, scales, aspect_ratios, model_config):
        super(RegionProposalNetwork, self).__init__()
        self.scales = scales
        self.low_iou_threshold = model_config['rpn_bg_threshold']
        self.high_iou_threshold = model_config['rpn_fg_threshold']
        self.rpn_nms_threshold = model_config['rpn_nms_threshold']
        self.rpn_batch_size = model_config['rpn_batch_size']
        self.rpn_pos_count = int(model_config['rpn_pos_fraction'] * self.rpn_batch_size)
        self.rpn_topk = model_config['rpn_train_topk'] if self.training else model_config['rpn_test_topk']
        self.rpn_prenms_topk = model_config['rpn_train_prenms_topk'] if self.training \
            else model_config['rpn_test_prenms_topk']
        self.aspect_ratios = aspect_ratios
        self.num_anchors = len(self.scales) * len(self.aspect_ratios)

        # 3x3 conv layer
        self.rpn_conv = nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1)

        # 1x1 classification conv layer
        self.cls_layer = nn.Conv2d(in_channels, self.num_anchors, kernel_size=1, stride=1)

        # 1x1 regression
        self.bbox_reg_layer = nn.Conv2d(in_channels, self.num_anchors * 4, kernel_size=1, stride=1)

        for layer in [self.rpn_conv, self.cls_layer, self.bbox_reg_layer]:
            torch.nn.init.normal_(layer.weight, std=0.01)
            torch.nn.init.constant_(layer.bias, 0)

    def generate_anchors(self, image, feat):
        r"""
        Method to generate anchors.
        """
        grid_h, grid_w = feat.shape[-2:]
        image_h, image_w = image.shape[-2:]

        # For the vgg16 case stride would be 16 for both h and w
        stride_h = torch.tensor(image_h // grid_h, dtype=torch.int64, device=feat.device)
        stride_w = torch.tensor(image_w // grid_w, dtype=torch.int64, device=feat.device)

        scales = torch.as_tensor(self.scales, dtype=feat.dtype, device=feat.device)
        aspect_ratios = torch.as_tensor(self.aspect_ratios, dtype=feat.dtype, device=feat.device)

        h_ratios = torch.sqrt(aspect_ratios)
        w_ratios = 1 / h_ratios

        ws = (w_ratios[:, None] * scales[None, :]).view(-1)
        hs = (h_ratios[:, None] * scales[None, :]).view(-1)

        # Base anchors (zero-centered)
        base_anchors = torch.stack([-ws, -hs, ws, hs], dim=1) / 2
        base_anchors = base_anchors.round()

        # Shifts
        shifts_x = torch.arange(0, grid_w, dtype=torch.int32, device=feat.device) * stride_w
        shifts_y = torch.arange(0, grid_h, dtype=torch.int32, device=feat.device) * stride_h

        shifts_y, shifts_x = torch.meshgrid(shifts_y, shifts_x, indexing="ij")

        shifts_x = shifts_x.reshape(-1)
        shifts_y = shifts_y.reshape(-1)
        shifts = torch.stack((shifts_x, shifts_y, shifts_x, shifts_y), dim=1)

        anchors = (shifts.view(-1, 1, 4) + base_anchors.view(1, -1, 4))
        anchors = anchors.reshape(-1, 4)
        return anchors

    def assign_targets_to_anchors(self, anchors, gt_boxes):
        # Get (gt_boxes, num_anchors_in_image) IOU matrix
        iou_matrix = get_iou(gt_boxes, anchors)

        best_match_iou, best_match_gt_idx = iou_matrix.max(dim=0)
        best_match_gt_idx_pre_thresholding = best_match_gt_idx.clone()

        below_low_threshold = best_match_iou < self.low_iou_threshold
        between_thresholds = (best_match_iou >= self.low_iou_threshold) & (best_match_iou < self.high_iou_threshold)
        best_match_gt_idx[below_low_threshold] = -1
        best_match_gt_idx[between_thresholds] = -2

        # Ensure every GT box has at least one anchor
        best_anchor_iou_for_gt, _ = iou_matrix.max(dim=1)
        gt_pred_pair_with_highest_iou = torch.where(iou_matrix == best_anchor_iou_for_gt[:, None])
        pred_inds_to_update = gt_pred_pair_with_highest_iou[1]
        best_match_gt_idx[pred_inds_to_update] = best_match_gt_idx_pre_thresholding[pred_inds_to_update]

        matched_gt_boxes = gt_boxes[best_match_gt_idx.clamp(min=0)]

        labels = best_match_gt_idx >= 0
        labels = labels.to(dtype=torch.float32)

        background_anchors = best_match_gt_idx == -1
        labels[background_anchors] = 0.0

        ignored_anchors = best_match_gt_idx == -2
        labels[ignored_anchors] = -1.0

        return labels, matched_gt_boxes

    def filter_proposals(self, proposals, cls_scores, image_shape):
        cls_scores = cls_scores.reshape(-1)
        cls_scores = torch.sigmoid(cls_scores)
        _, top_n_idx = cls_scores.topk(min(self.rpn_prenms_topk, len(cls_scores)))

        cls_scores = cls_scores[top_n_idx]
        proposals = proposals[top_n_idx]

        proposals = clamp_boxes_to_image_boundary(proposals, image_shape)

        min_size = 16
        ws, hs = proposals[:, 2] - proposals[:, 0], proposals[:, 3] - proposals[:, 1]
        keep = (ws >= min_size) & (hs >= min_size)
        keep = torch.where(keep)[0]
        proposals = proposals[keep]
        cls_scores = cls_scores[keep]

        keep_mask = torch.zeros_like(cls_scores, dtype=torch.bool)
        keep_indices = torch.ops.torchvision.nms(proposals, cls_scores, self.rpn_nms_threshold)
        keep_mask[keep_indices] = True
        keep_indices = torch.where(keep_mask)[0]

        post_nms_keep_indices = keep_indices[cls_scores[keep_indices].sort(descending=True)[1]]

        proposals, cls_scores = (proposals[post_nms_keep_indices[:self.rpn_topk]],
                                 cls_scores[post_nms_keep_indices[:self.rpn_topk]])

        return proposals, cls_scores

    def forward(self, image, feat, target=None):
        rpn_feat = nn.ReLU()(self.rpn_conv(feat))
        cls_scores = self.cls_layer(rpn_feat)
        box_transform_pred = self.bbox_reg_layer(rpn_feat)

        anchors = self.generate_anchors(image, feat)

        number_of_anchors_per_location = cls_scores.size(1)
        cls_scores = cls_scores.permute(0, 2, 3, 1)
        cls_scores = cls_scores.reshape(-1, 1)

        box_transform_pred = box_transform_pred.view(
            box_transform_pred.size(0),
            number_of_anchors_per_location,
            4,
            rpn_feat.shape[-2],
            rpn_feat.shape[-1])
        box_transform_pred = box_transform_pred.permute(0, 3, 4, 1, 2)
        box_transform_pred = box_transform_pred.reshape(-1, 4)

        proposals = apply_regression_pred_to_anchors_or_proposals(
            box_transform_pred.detach().reshape(-1, 1, 4),
            anchors)
        proposals = proposals.reshape(proposals.size(0), 4)

        proposals, scores = self.filter_proposals(proposals, cls_scores.detach(), image.shape)
        rpn_output = {
            'proposals': proposals,
            'scores': scores
        }
        if not self.training or target is None:
            return rpn_output
        else:
            labels_for_anchors, matched_gt_boxes_for_anchors = self.assign_targets_to_anchors(
                anchors,
                target['bboxes'][0])

            regression_targets = boxes_to_transformation_targets(matched_gt_boxes_for_anchors, anchors)

            sampled_neg_idx_mask, sampled_pos_idx_mask = sample_positive_negative(
                labels_for_anchors,
                positive_count=self.rpn_pos_count,
                total_count=self.rpn_batch_size)

            sampled_idxs = torch.where(sampled_pos_idx_mask | sampled_neg_idx_mask)[0]

            localization_loss = (
                    torch.nn.functional.smooth_l1_loss(
                        box_transform_pred[sampled_pos_idx_mask],
                        regression_targets[sampled_pos_idx_mask],
                        beta=1 / 9,
                        reduction="sum",
                    )
                    / (sampled_idxs.numel())
            )

            cls_loss = torch.nn.functional.binary_cross_entropy_with_logits(cls_scores[sampled_idxs].flatten(),
                                                                            labels_for_anchors[sampled_idxs].flatten())

            rpn_output['rpn_classification_loss'] = cls_loss
            rpn_output['rpn_localization_loss'] = localization_loss
            return rpn_output


class ROIHead(nn.Module):
    r"""
    ROI head on top of ROI pooling layer.
    """

    def __init__(self, model_config, num_classes, in_channels):
        super(ROIHead, self).__init__()
        self.num_classes = num_classes
        self.roi_batch_size = model_config['roi_batch_size']
        self.roi_pos_count = int(model_config['roi_pos_fraction'] * self.roi_batch_size)
        self.iou_threshold = model_config['roi_iou_threshold']
        self.low_bg_iou = model_config['roi_low_bg_iou']
        self.nms_threshold = model_config['roi_nms_threshold']
        self.topK_detections = model_config['roi_topk_detections']
        self.low_score_threshold = model_config['roi_score_threshold']
        self.pool_size = model_config['roi_pool_size']
        self.fc_inner_dim = model_config['fc_inner_dim']

        self.fc6 = nn.Linear(in_channels * self.pool_size * self.pool_size, self.fc_inner_dim)
        self.fc7 = nn.Linear(self.fc_inner_dim, self.fc_inner_dim)
        self.cls_layer = nn.Linear(self.fc_inner_dim, self.num_classes)
        self.bbox_reg_layer = nn.Linear(self.fc_inner_dim, self.num_classes * 4)

        torch.nn.init.normal_(self.cls_layer.weight, std=0.01)
        torch.nn.init.constant_(self.cls_layer.bias, 0)

        torch.nn.init.normal_(self.bbox_reg_layer.weight, std=0.001)
        torch.nn.init.constant_(self.bbox_reg_layer.bias, 0)

    def assign_target_to_proposals(self, proposals, gt_boxes, gt_labels):
        iou_matrix = get_iou(gt_boxes, proposals)
        best_match_iou, best_match_gt_idx = iou_matrix.max(dim=0)
        background_proposals = (best_match_iou < self.iou_threshold) & (best_match_iou >= self.low_bg_iou)
        ignored_proposals = best_match_iou < self.low_bg_iou

        best_match_gt_idx[background_proposals] = -1
        best_match_gt_idx[ignored_proposals] = -2

        matched_gt_boxes_for_proposals = gt_boxes[best_match_gt_idx.clamp(min=0)]
        labels = gt_labels[best_match_gt_idx.clamp(min=0)]
        labels = labels.to(dtype=torch.int64)

        labels[background_proposals] = 0
        labels[ignored_proposals] = -1

        return labels, matched_gt_boxes_for_proposals

    def forward(self, feat, proposals, image_shape, target):
        if self.training and target is not None:
            proposals = torch.cat([proposals, target['bboxes'][0]], dim=0)

            gt_boxes = target['bboxes'][0]
            gt_labels = target['labels'][0]

            labels, matched_gt_boxes_for_proposals = self.assign_target_to_proposals(proposals, gt_boxes, gt_labels)

            sampled_neg_idx_mask, sampled_pos_idx_mask = sample_positive_negative(labels,
                                                                                  positive_count=self.roi_pos_count,
                                                                                  total_count=self.roi_batch_size)

            sampled_idxs = torch.where(sampled_pos_idx_mask | sampled_neg_idx_mask)[0]

            proposals = proposals[sampled_idxs]
            labels = labels[sampled_idxs]
            matched_gt_boxes_for_proposals = matched_gt_boxes_for_proposals[sampled_idxs]
            regression_targets = boxes_to_transformation_targets(matched_gt_boxes_for_proposals, proposals)

        # ROI Pooling logic
        size = feat.shape[-2:]
        possible_scales = []
        for s1, s2 in zip(size, image_shape):
            approx_scale = float(s1) / float(s2)
            scale = 2 ** float(torch.tensor(approx_scale).log2().round())
            possible_scales.append(scale)
        assert possible_scales[0] == possible_scales[1]

        #
        proposal_roi_pool_feats = torchvision.ops.roi_pool(feat, [proposals],
                                                           output_size=self.pool_size,
                                                           spatial_scale=possible_scales[0])
        proposal_roi_pool_feats = proposal_roi_pool_feats.flatten(start_dim=1)
        box_fc_6 = torch.nn.functional.relu(self.fc6(proposal_roi_pool_feats))
        box_fc_7 = torch.nn.functional.relu(self.fc7(box_fc_6))
        cls_scores = self.cls_layer(box_fc_7)
        box_transform_pred = self.bbox_reg_layer(box_fc_7)

        num_boxes, num_classes = cls_scores.shape
        box_transform_pred = box_transform_pred.reshape(num_boxes, num_classes, 4)
        frcnn_output = {}
        if self.training and target is not None:
            classification_loss = torch.nn.functional.cross_entropy(cls_scores, labels)

            fg_proposals_idxs = torch.where(labels > 0)[0]
            fg_cls_labels = labels[fg_proposals_idxs]

            localization_loss = torch.nn.functional.smooth_l1_loss(
                box_transform_pred[fg_proposals_idxs, fg_cls_labels],
                regression_targets[fg_proposals_idxs],
                beta=1/9,
                reduction="sum",
            )
            localization_loss = localization_loss / labels.numel()
            frcnn_output['frcnn_classification_loss'] = classification_loss
            frcnn_output['frcnn_localization_loss'] = localization_loss

        if self.training:
            return frcnn_output
        else:
            device = cls_scores.device
            pred_boxes = apply_regression_pred_to_anchors_or_proposals(box_transform_pred, proposals)
            pred_scores = torch.nn.functional.softmax(cls_scores, dim=-1)

            pred_boxes = clamp_boxes_to_image_boundary(pred_boxes, image_shape)

            pred_labels = torch.arange(num_classes, device=device)
            pred_labels = pred_labels.view(1, -1).expand_as(pred_scores)

            pred_boxes = pred_boxes[:, 1:]
            pred_scores = pred_scores[:, 1:]
            pred_labels = pred_labels[:, 1:]

            pred_boxes = pred_boxes.reshape(-1, 4)
            pred_scores = pred_scores.reshape(-1)
            pred_labels = pred_labels.reshape(-1)

            pred_boxes, pred_labels, pred_scores = self.filter_predictions(pred_boxes, pred_labels, pred_scores)
            frcnn_output['boxes'] = pred_boxes
            frcnn_output['scores'] = pred_scores
            frcnn_output['labels'] = pred_labels
            return frcnn_output

    def filter_predictions(self, pred_boxes, pred_labels, pred_scores):
        keep = torch.where(pred_scores > self.low_score_threshold)[0]
        pred_boxes, pred_scores, pred_labels = pred_boxes[keep], pred_scores[keep], pred_labels[keep]

        min_size = 16
        ws, hs = pred_boxes[:, 2] - pred_boxes[:, 0], pred_boxes[:, 3] - pred_boxes[:, 1]
        keep = (ws >= min_size) & (hs >= min_size)
        keep = torch.where(keep)[0]
        pred_boxes, pred_scores, pred_labels = pred_boxes[keep], pred_scores[keep], pred_labels[keep]

        keep_mask = torch.zeros_like(pred_scores, dtype=torch.bool)
        for class_id in torch.unique(pred_labels):
            curr_indices = torch.where(pred_labels == class_id)[0]
            curr_keep_indices = torch.ops.torchvision.nms(pred_boxes[curr_indices],
                                                          pred_scores[curr_indices],
                                                          self.nms_threshold)
            keep_mask[curr_indices[curr_keep_indices]] = True
        keep_indices = torch.where(keep_mask)[0]
        post_nms_keep_indices = keep_indices[pred_scores[keep_indices].sort(descending=True)[1]]
        keep = post_nms_keep_indices[:self.topK_detections]
        pred_boxes, pred_scores, pred_labels = pred_boxes[keep], pred_scores[keep], pred_labels[keep]
        return pred_boxes, pred_labels, pred_scores


class FasterRCNN(nn.Module):
    #
    def __init__(self, model_config, num_classes):
        super(FasterRCNN, self).__init__()
        self.model_config = model_config
        # Ensure we are not using pretrained weights for the 'from scratch' requirement
        vgg16 = torchvision.models.vgg16(pretrained=False)
        self.backbone = vgg16.features[:-1]
        self.rpn = RegionProposalNetwork(model_config['backbone_out_channels'],
                                         scales=model_config['scales'],
                                         aspect_ratios=model_config['aspect_ratios'],
                                         model_config=model_config)
        self.roi_head = ROIHead(model_config, num_classes, in_channels=model_config['backbone_out_channels'])

        # REMOVED: The freezing loop. For 'train from scratch', we must train the backbone.
        # for layer in self.backbone[:10]:
        #     for p in layer.parameters():
        #         p.requires_grad = False

        self.image_mean = [0.485, 0.456, 0.406]
        self.image_std = [0.229, 0.224, 0.225]
        self.min_size = model_config['min_im_size']
        self.max_size = model_config['max_im_size']

    def normalize_resize_image_and_boxes(self, image, bboxes):
        dtype, device = image.dtype, image.device

        mean = torch.as_tensor(self.image_mean, dtype=dtype, device=device)
        std = torch.as_tensor(self.image_std, dtype=dtype, device=device)
        image = (image - mean[:, None, None]) / std[:, None, None]

        h, w = image.shape[-2:]
        im_shape = torch.tensor(image.shape[-2:])
        min_size = torch.min(im_shape).to(dtype=torch.float32)
        max_size = torch.max(im_shape).to(dtype=torch.float32)
        scale = torch.min(float(self.min_size) / min_size, float(self.max_size) / max_size)
        scale_factor = scale.item()

        image = torch.nn.functional.interpolate(
            image,
            size=None,
            scale_factor=scale_factor,
            mode="bilinear",
            recompute_scale_factor=True,
            align_corners=False,
        )

        if bboxes is not None:
            ratios = [
                torch.tensor(s, dtype=torch.float32, device=bboxes.device)
                / torch.tensor(s_orig, dtype=torch.float32, device=bboxes.device)
                for s, s_orig in zip(image.shape[-2:], (h, w))
            ]
            ratio_height, ratio_width = ratios
            xmin, ymin, xmax, ymax = bboxes.unbind(2)
            xmin = xmin * ratio_width
            xmax = xmax * ratio_width
            ymin = ymin * ratio_height
            ymax = ymax * ratio_height
            bboxes = torch.stack((xmin, ymin, xmax, ymax), dim=2)
        return image, bboxes

    def forward(self, image, target=None):
        old_shape = image.shape[-2:]
        if self.training:
            image, bboxes = self.normalize_resize_image_and_boxes(image, target['bboxes'])
            target['bboxes'] = bboxes
        else:
            image, _ = self.normalize_resize_image_and_boxes(image, None)

        feat = self.backbone(image)

        rpn_output = self.rpn(image, feat, target)
        proposals = rpn_output['proposals']

        frcnn_output = self.roi_head(feat, proposals, image.shape[-2:], target)
        if not self.training:
            frcnn_output['boxes'] = transform_boxes_to_original_size(frcnn_output['boxes'],
                                                                     image.shape[-2:],
                                                                     old_shape)
        return rpn_output, frcnn_output
# Out:
# Overwriting faster_rcnn.py

# %%
# %%writefile video_demo.py
import torch
import cv2
import argparse
import yaml
import time
import os
import numpy as np
from faster_rcnn import FasterRCNN

def get_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    return torch.device('cpu')

device = get_device()

raw_classes = [
    'person', 'bird', 'cat', 'cow', 'dog', 'horse', 'sheep',
    'aeroplane', 'bicycle', 'boat', 'bus', 'car', 'motorbike', 'train',
    'bottle', 'chair', 'diningtable', 'pottedplant', 'sofa', 'tvmonitor'
]
VOC_CLASSES = ['background'] + sorted(raw_classes)

# ---- inference settings (must match training) ----
INFER_SIZE = 800
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)

def run_video(args):
    with open(args.config_path, 'r') as f:
        config = yaml.safe_load(f)

    model = FasterRCNN(
        config['model_params'],
        num_classes=config['dataset_params']['num_classes']
    )

    ckpt_path = config['train_params']['ckpt_name']
    model.load_state_dict(torch.load(ckpt_path, map_location=device))
    model.to(device).eval()

    cap = cv2.VideoCapture(args.video_path)
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    if fps == 0:
        fps = 20

    writer = cv2.VideoWriter(
        'output_demo.avi',
        cv2.VideoWriter_fourcc(*'MJPG'),
        fps,
        (width, height)
    )

    print(f"Processing video {width}x{height}...")

    with torch.no_grad():
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            # ---- preprocessing (FIXED) ----
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            resized = cv2.resize(frame_rgb, (INFER_SIZE, INFER_SIZE))

            img_tensor = torch.from_numpy(resized).permute(2, 0, 1).float() / 255.0
            img_tensor = (img_tensor - IMAGENET_MEAN) / IMAGENET_STD
            img_tensor = img_tensor.unsqueeze(0).to(device)

            _, frcnn_output = model(img_tensor, None)

            if len(frcnn_output['scores']) > 0:
                print(f"Max score in frame: {torch.max(frcnn_output['scores']).item():.4f}")
            else:
                print("No objects detected at all.")

            # ---- rescale boxes back to original frame ----
            scale_x = width / INFER_SIZE
            scale_y = height / INFER_SIZE

            for box, label, score in zip(
                frcnn_output['boxes'],
                frcnn_output['labels'],
                frcnn_output['scores']
            ):
                if score < args.threshold:
                    continue

                box = box.cpu().numpy()
                x1 = int(box[0] * scale_x)
                y1 = int(box[1] * scale_y)
                x2 = int(box[2] * scale_x)
                y2 = int(box[3] * scale_y)

                cls_id = label.item()
                cls_name = VOC_CLASSES[cls_id] if cls_id < len(VOC_CLASSES) else str(cls_id)

                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(
                    frame,
                    f"{cls_name} {score:.2f}",
                    (x1, max(0, y1 - 10)),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5,
                    (0, 255, 0),
                    2
                )

            writer.write(frame)

    cap.release()
    writer.release()
    print("Video saved to output_demo.avi")

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--config', dest='config_path', default='config/voc.yaml')
    parser.add_argument('--video_path', required=True)
    parser.add_argument('--threshold', type=float, default=0.7)
    args = parser.parse_args()
    run_video(args)
# Out:
# Overwriting video_demo.py

# %%
import os

# 1. Define your list of input videos
video_files = [
    'car-detection.mp4',
    'one-by-one-person-detection.mp4',
    'person-bicycle-car-detection.mp4',
    'fruit-and-vegetable-detection.mp4'
]

# 2. Path to your best checkpoint
# Ensure this matches the file you saved/downloaded earlier
best_ckpt = "faster_rcnn_voc_scratch.pth"

# 3. Loop through and process
for video in video_files:
    if os.path.exists(video):
        print(f"--- Processing {video} ---")
        # We define a unique output name for each
        output_name = f"processed_{os.path.splitext(video)[0]}.avi"

        # Call the demo script
        # !PYTHONPATH=. python video_demo.py \
            --config voc.yaml \
            --video_path {video} \
            --threshold 0.95

        # Optional: Rename the generic 'output_demo.avi' to our unique name
        if os.path.exists('output_demo.avi'):
            os.rename('output_demo.avi', output_name)
            print(f"Finished: Saved to {output_name}")
    else:
        print(f"File {video} not found. Skipping.")
# Out:
# --- Processing car-detection.mp4 ---
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Processing video 768x432...
# Max score in frame: 0.5299
# Max score in frame: 0.5271
# Max score in frame: 0.5264
# Max score in frame: 0.5599
# Max score in frame: 0.4500
# Max score in frame: 0.5242
# Max score in frame: 0.5277
# Max score in frame: 0.4631
# Max score in frame: 0.5197
# Max score in frame: 0.4806
# Max score in frame: 0.5200
# Max score in frame: 0.4951
# Max score in frame: 0.5328
# Max score in frame: 0.5479
# Max score in frame: 0.6173
# Max score in frame: 0.5407
# Max score in frame: 0.5202
# Max score in frame: 0.5312
# Max score in frame: 0.6117
# Max score in frame: 0.4751
# Max score in frame: 0.4777
# Max score in frame: 0.5184
# Max score in frame: 0.4953
# Max score in frame: 0.4829
# Max score in frame: 0.4758
# Max score in frame: 0.5187
# Max score in frame: 0.5099
# Max score in frame: 0.5001
# Max score in frame: 0.5040
# Max score in frame: 0.4324
# Max score in frame: 0.5381
# Max score in frame: 0.5324
# Max score in frame: 0.5510
# Max score in frame: 0.4760
# Max score in frame: 0.5321
# Max score in frame: 0.5408
# Max score in frame: 0.5636
# Max score in frame: 0.5451
# Max score in frame: 0.4867
# Max score in frame: 0.4667
# Max score in frame: 0.4172
# Max score in frame: 0.4229
# Max score in frame: 0.4845
# Max score in frame: 0.4810
# Max score in frame: 0.4340
# Max score in frame: 0.4785
# Max score in frame: 0.5367
# Max score in frame: 0.4768
# Max score in frame: 0.4202
# Max score in frame: 0.5346
# Max score in frame: 0.4994
# Max score in frame: 0.4257
# Max score in frame: 0.5291
# Max score in frame: 0.5322
# Max score in frame: 0.5328
# Max score in frame: 0.5898
# Max score in frame: 0.6905
# Max score in frame: 0.6341
# Max score in frame: 0.6290
# Max score in frame: 0.6785
# Max score in frame: 0.5977
# Max score in frame: 0.4045
# Max score in frame: 0.5417
# Max score in frame: 0.5799
# Max score in frame: 0.4809
# Max score in frame: 0.8123
# Max score in frame: 0.8628
# Max score in frame: 0.9078
# Max score in frame: 0.8634
# Max score in frame: 0.9580
# Max score in frame: 0.8679
# Max score in frame: 0.8245
# Max score in frame: 0.9296
# Max score in frame: 0.9615
# Max score in frame: 0.9523
# Max score in frame: 0.9942
# Max score in frame: 0.9579
# Max score in frame: 0.9701
# Max score in frame: 0.9871
# Max score in frame: 0.9893
# Max score in frame: 0.9837
# Max score in frame: 0.9867
# Max score in frame: 0.9978
# Max score in frame: 0.9727
# Max score in frame: 0.9793
# Max score in frame: 0.9866
# Max score in frame: 0.9825
# Max score in frame: 0.9636
# Max score in frame: 0.9114
# Max score in frame: 0.8672
# Max score in frame: 0.8591
# Max score in frame: 0.8227
# Max score in frame: 0.8935
# Max score in frame: 0.9259
# Max score in frame: 0.9790
# Max score in frame: 0.9878
# Max score in frame: 0.9980
# Max score in frame: 0.9944
# Max score in frame: 0.9922
# Max score in frame: 0.9908
# Max score in frame: 0.9991
# Max score in frame: 0.9944
# Max score in frame: 0.9990
# Max score in frame: 0.9917
# Max score in frame: 0.9355
# Max score in frame: 0.9144
# Max score in frame: 0.8636
# Max score in frame: 0.7882
# Max score in frame: 0.8187
# Max score in frame: 0.7869
# Max score in frame: 0.7245
# Max score in frame: 0.7188
# Max score in frame: 0.6169
# Max score in frame: 0.6075
# Max score in frame: 0.6034
# Max score in frame: 0.6387
# Max score in frame: 0.6317
# Max score in frame: 0.5442
# Max score in frame: 0.6276
# Max score in frame: 0.6345
# Max score in frame: 0.5319
# Max score in frame: 0.6115
# Max score in frame: 0.6129
# Max score in frame: 0.6184
# Max score in frame: 0.6137
# Max score in frame: 0.6039
# Max score in frame: 0.5980
# Max score in frame: 0.5195
# Max score in frame: 0.5969
# Max score in frame: 0.6104
# Max score in frame: 0.5147
# Max score in frame: 0.5135
# Max score in frame: 0.4792
# Max score in frame: 0.5175
# Max score in frame: 0.5019
# Max score in frame: 0.5075
# Max score in frame: 0.4971
# Max score in frame: 0.4996
# Max score in frame: 0.5928
# Max score in frame: 0.5115
# Max score in frame: 0.6033
# Max score in frame: 0.5212
# Max score in frame: 0.4761
# Max score in frame: 0.5101
# Max score in frame: 0.5188
# Max score in frame: 0.5062
# Max score in frame: 0.5842
# Max score in frame: 0.5051
# Max score in frame: 0.4808
# Max score in frame: 0.5139
# Max score in frame: 0.5961
# Max score in frame: 0.4905
# Max score in frame: 0.6001
# Max score in frame: 0.4978
# Max score in frame: 0.5001
# Max score in frame: 0.5842
# Max score in frame: 0.5302
# Max score in frame: 0.4592
# Max score in frame: 0.4346
# Max score in frame: 0.5966
# Max score in frame: 0.5996
# Max score in frame: 0.5169
# Max score in frame: 0.4880
# Max score in frame: 0.5572
# Max score in frame: 0.5768
# Max score in frame: 0.5265
# Max score in frame: 0.6154
# Max score in frame: 0.4804
# Max score in frame: 0.6289
# Max score in frame: 0.6093
# Max score in frame: 0.5232
# Max score in frame: 0.5147
# Max score in frame: 0.5247
# Max score in frame: 0.5063
# Max score in frame: 0.5914
# Max score in frame: 0.5390
# Max score in frame: 0.5350
# Max score in frame: 0.5030
# Max score in frame: 0.5223
# Max score in frame: 0.5718
# Max score in frame: 0.6870
# Max score in frame: 0.6967
# Max score in frame: 0.7695
# Max score in frame: 0.9901
# Max score in frame: 0.9984
# Max score in frame: 0.9941
# Max score in frame: 0.9903
# Max score in frame: 0.9970
# Max score in frame: 0.9946
# Max score in frame: 0.9989
# Max score in frame: 0.9956
# Max score in frame: 0.9970
# Max score in frame: 0.9969
# Max score in frame: 0.9911
# Max score in frame: 0.9907
# Max score in frame: 0.9944
# Max score in frame: 0.9944
# Max score in frame: 0.9931
# Max score in frame: 0.9608
# Max score in frame: 0.9774
# Max score in frame: 0.9772
# Max score in frame: 0.9791
# Max score in frame: 0.9941
# Max score in frame: 0.9862
# Max score in frame: 0.9779
# Max score in frame: 0.9808
# Max score in frame: 0.9882
# Max score in frame: 0.9965
# Max score in frame: 0.9987
# Max score in frame: 0.9973
# Max score in frame: 0.9985
# Max score in frame: 0.9989
# Max score in frame: 0.9943
# Max score in frame: 0.9933
# Max score in frame: 0.9825
# Max score in frame: 0.9945
# Max score in frame: 0.9855
# Max score in frame: 0.9948
# Max score in frame: 0.9902
# Max score in frame: 0.9971
# Max score in frame: 0.9992
# Max score in frame: 0.9997
# Max score in frame: 0.9952
# Max score in frame: 0.9796
# Max score in frame: 0.9906
# Max score in frame: 0.9909
# Max score in frame: 0.9500
# Max score in frame: 0.9618
# Max score in frame: 0.8979
# Max score in frame: 0.9717
# Max score in frame: 0.9510
# Max score in frame: 0.8666
# Max score in frame: 0.8857
# Max score in frame: 0.9644
# Max score in frame: 0.8919
# Max score in frame: 0.9534
# Max score in frame: 0.8873
# Max score in frame: 0.7850
# Max score in frame: 0.8357
# Max score in frame: 0.7140
# Max score in frame: 0.6461
# Max score in frame: 0.5180
# Max score in frame: 0.5061
# Max score in frame: 0.6160
# Max score in frame: 0.5645
# Max score in frame: 0.6023
# Max score in frame: 0.5907
# Max score in frame: 0.5412
# Max score in frame: 0.5295
# Max score in frame: 0.5004
# Max score in frame: 0.5791
# Max score in frame: 0.5030
# Max score in frame: 0.5212
# Max score in frame: 0.4902
# Max score in frame: 0.4866
# Max score in frame: 0.4958
# Max score in frame: 0.4935
# Max score in frame: 0.4908
# Max score in frame: 0.4952
# Max score in frame: 0.4895
# Max score in frame: 0.5104
# Max score in frame: 0.4873
# Max score in frame: 0.5852
# Max score in frame: 0.5910
# Max score in frame: 0.5840
# Max score in frame: 0.4900
# Max score in frame: 0.5786
# Max score in frame: 0.5846
# Max score in frame: 0.5061
# Max score in frame: 0.5108
# Max score in frame: 0.5105
# Max score in frame: 0.5172
# Max score in frame: 0.4913
# Max score in frame: 0.4971
# Max score in frame: 0.5817
# Max score in frame: 0.5862
# Max score in frame: 0.5902
# Max score in frame: 0.4987
# Max score in frame: 0.5803
# Max score in frame: 0.5045
# Max score in frame: 0.5192
# Max score in frame: 0.5786
# Max score in frame: 0.5072
# Max score in frame: 0.5242
# Max score in frame: 0.5193
# Max score in frame: 0.5039
# Max score in frame: 0.5121
# Max score in frame: 0.5107
# Max score in frame: 0.5775
# Max score in frame: 0.5751
# Max score in frame: 0.4926
# Max score in frame: 0.5067
# Max score in frame: 0.5049
# Max score in frame: 0.4931
# Max score in frame: 0.4903
# Max score in frame: 0.4933
# Max score in frame: 0.5032
# Max score in frame: 0.5045
# Max score in frame: 0.5076
# Max score in frame: 0.5879
# Max score in frame: 0.5037
# Max score in frame: 0.5019
# Max score in frame: 0.5008
# Max score in frame: 0.4862
# Max score in frame: 0.4825
# Max score in frame: 0.4821
# Max score in frame: 0.4813
# Max score in frame: 0.4844
# Max score in frame: 0.5053
# Max score in frame: 0.5024
# Max score in frame: 0.4990
# Max score in frame: 0.5014
# Max score in frame: 0.5650
# Max score in frame: 0.4975
# Max score in frame: 0.5043
# Max score in frame: 0.6323
# Max score in frame: 0.9842
# Max score in frame: 0.9953
# Max score in frame: 0.9918
# Max score in frame: 0.9986
# Max score in frame: 0.9730
# Max score in frame: 0.9866
# Max score in frame: 0.9960
# Max score in frame: 0.9760
# Max score in frame: 0.9763
# Max score in frame: 0.9517
# Max score in frame: 0.9470
# Max score in frame: 0.9380
# Max score in frame: 0.8879
# Max score in frame: 0.8605
# Max score in frame: 0.8066
# Max score in frame: 0.8626
# Max score in frame: 0.8882
# Max score in frame: 0.9265
# Max score in frame: 0.9814
# Max score in frame: 0.9680
# Max score in frame: 0.9890
# Max score in frame: 0.9913
# Max score in frame: 0.9785
# Max score in frame: 0.9960
# Max score in frame: 0.9825
# Max score in frame: 0.9980
# Max score in frame: 0.9925
# Max score in frame: 0.9882
# Max score in frame: 0.9735
# Max score in frame: 0.9866
# Max score in frame: 0.9661
# Max score in frame: 0.9692
# Max score in frame: 0.7432
# Max score in frame: 0.7649
# Max score in frame: 0.7269
# Max score in frame: 0.9496
# Max score in frame: 0.9524
# Max score in frame: 0.9123
# Max score in frame: 0.8581
# Max score in frame: 0.8670
# Max score in frame: 0.8559
# Max score in frame: 0.8182
# Max score in frame: 0.7857
# Max score in frame: 0.6502
# Max score in frame: 0.7853
# Max score in frame: 0.9126
# Max score in frame: 0.8605
# Max score in frame: 0.6899
# Max score in frame: 0.7747
# Max score in frame: 0.8361
# Max score in frame: 0.7594
# Max score in frame: 0.7158
# Max score in frame: 0.7461
# Max score in frame: 0.6503
# Max score in frame: 0.5950
# Max score in frame: 0.7125
# Max score in frame: 0.5768
# Max score in frame: 0.5142
# Max score in frame: 0.5391
# Max score in frame: 0.5410
# Max score in frame: 0.5464
# Video saved to output_demo.avi
# Finished: Saved to processed_car-detection.avi
# --- Processing one-by-one-person-detection.mp4 ---
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Processing video 768x432...
# Max score in frame: 0.9565
# Max score in frame: 0.9561
# Max score in frame: 0.9561
# Max score in frame: 0.9561
# Max score in frame: 0.9560
# Max score in frame: 0.9559
# Max score in frame: 0.9559
# Max score in frame: 0.9560
# Max score in frame: 0.9556
# Max score in frame: 0.9555
# Max score in frame: 0.9559
# Max score in frame: 0.9550
# Max score in frame: 0.9550
# Max score in frame: 0.9550
# Max score in frame: 0.9548
# Max score in frame: 0.9547
# Max score in frame: 0.9547
# Max score in frame: 0.9547
# Max score in frame: 0.9554
# Max score in frame: 0.9556
# Max score in frame: 0.9534
# Max score in frame: 0.9529
# Max score in frame: 0.9526
# Max score in frame: 0.9528
# Max score in frame: 0.9529
# Max score in frame: 0.9536
# Max score in frame: 0.9536
# Max score in frame: 0.9536
# Max score in frame: 0.9539
# Max score in frame: 0.9538
# Max score in frame: 0.9489
# Max score in frame: 0.9470
# Max score in frame: 0.9469
# Max score in frame: 0.9469
# Max score in frame: 0.9468
# Max score in frame: 0.9459
# Max score in frame: 0.9458
# Max score in frame: 0.9453
# Max score in frame: 0.9454
# Max score in frame: 0.9453
# Max score in frame: 0.9564
# Max score in frame: 0.9561
# Max score in frame: 0.9562
# Max score in frame: 0.9562
# Max score in frame: 0.9563
# Max score in frame: 0.9559
# Max score in frame: 0.9559
# Max score in frame: 0.9559
# Max score in frame: 0.9557
# Max score in frame: 0.9558
# Max score in frame: 0.9421
# Max score in frame: 0.9411
# Max score in frame: 0.9411
# Max score in frame: 0.9411
# Max score in frame: 0.9396
# Max score in frame: 0.9194
# Max score in frame: 0.9202
# Max score in frame: 0.9213
# Max score in frame: 0.9579
# Max score in frame: 0.9573
# Max score in frame: 0.9965
# Max score in frame: 0.9946
# Max score in frame: 0.9230
# Max score in frame: 0.9335
# Max score in frame: 0.7746
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9998
# Max score in frame: 0.9999
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9999
# Max score in frame: 0.9998
# Max score in frame: 0.9998
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9998
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9998
# Max score in frame: 0.9998
# Max score in frame: 0.9998
# Max score in frame: 0.9999
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9998
# Max score in frame: 0.9998
# Max score in frame: 1.0000
# Max score in frame: 0.9998
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9998
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9999
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9999
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9999
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9991
# Max score in frame: 0.9994
# Max score in frame: 0.9966
# Max score in frame: 0.9909
# Max score in frame: 0.9930
# Max score in frame: 0.9913
# Max score in frame: 0.9694
# Max score in frame: 0.9461
# Max score in frame: 0.9402
# Max score in frame: 0.9571
# Max score in frame: 0.9707
# Max score in frame: 0.9708
# Max score in frame: 0.9496
# Max score in frame: 0.9480
# Max score in frame: 0.9443
# Max score in frame: 0.9397
# Max score in frame: 0.9407
# Max score in frame: 0.9407
# Max score in frame: 0.9408
# Max score in frame: 0.9689
# Max score in frame: 0.9689
# Max score in frame: 0.9688
# Max score in frame: 0.9689
# Max score in frame: 0.9689
# Max score in frame: 0.9686
# Max score in frame: 0.9686
# Max score in frame: 0.9686
# Max score in frame: 0.9683
# Max score in frame: 0.9678
# Max score in frame: 0.9503
# Max score in frame: 0.9499
# Max score in frame: 0.9497
# Max score in frame: 0.9504
# Max score in frame: 0.9536
# Max score in frame: 0.9552
# Max score in frame: 0.9537
# Max score in frame: 0.9965
# Max score in frame: 0.9783
# Max score in frame: 0.9410
# Max score in frame: 0.9699
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 1.0000
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9898
# Max score in frame: 0.9967
# Max score in frame: 0.9934
# Max score in frame: 0.9946
# Max score in frame: 0.9837
# Max score in frame: 0.9659
# Max score in frame: 0.9660
# Max score in frame: 0.9587
# Max score in frame: 0.9475
# Max score in frame: 0.9275
# Max score in frame: 0.9302
# Max score in frame: 0.9514
# Max score in frame: 0.9441
# Max score in frame: 0.9623
# Max score in frame: 0.9641
# Max score in frame: 0.9641
# Max score in frame: 0.9459
# Max score in frame: 0.9459
# Max score in frame: 0.9450
# Max score in frame: 0.9455
# Max score in frame: 0.9490
# Max score in frame: 0.9488
# Max score in frame: 0.9488
# Max score in frame: 0.9490
# Max score in frame: 0.9487
# Max score in frame: 0.9489
# Max score in frame: 0.9523
# Max score in frame: 0.9524
# Max score in frame: 0.9543
# Max score in frame: 0.9550
# Max score in frame: 0.9551
# Max score in frame: 0.9550
# Max score in frame: 0.9559
# Max score in frame: 0.9559
# Max score in frame: 0.9559
# Max score in frame: 0.9558
# Max score in frame: 0.9546
# Max score in frame: 0.9443
# Max score in frame: 0.9538
# Max score in frame: 0.9436
# Max score in frame: 0.9540
# Max score in frame: 0.9542
# Max score in frame: 0.9542
# Max score in frame: 0.9541
# Max score in frame: 0.9543
# Max score in frame: 0.9554
# Max score in frame: 0.9500
# Max score in frame: 0.9510
# Max score in frame: 0.9513
# Max score in frame: 0.9510
# Max score in frame: 0.9516
# Traceback (most recent call last):
#   File "/content/video_demo.py", line 123, in <module>
#     run_video(args)
#   File "/content/video_demo.py", line 72, in run_video
#     _, frcnn_output = model(img_tensor, None)
#                       ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/faster_rcnn.py", line 584, in forward
#     rpn_output = self.rpn(image, feat, target)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/faster_rcnn.py", line 298, in forward
#     anchors = self.generate_anchors(image, feat)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/faster_rcnn.py", line 203, in generate_anchors
#     stride_h = torch.tensor(image_h // grid_h, dtype=torch.int64, device=feat.device)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C
# Finished: Saved to processed_one-by-one-person-detection.avi
# --- Processing person-bicycle-car-detection.mp4 ---
# Traceback (most recent call last):
# object address  : 0x791f5895d8a0
# object refcount : 3
# object type     : 0xa2a4e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C
# --- Processing fruit-and-vegetable-detection.mp4 ---
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Processing video 960x540...
# Max score in frame: 0.1813
# Max score in frame: 0.1800
# Max score in frame: 0.1824
# Max score in frame: 0.1538
# Max score in frame: 0.1821
# Max score in frame: 0.1775
# Max score in frame: 0.1819
# Max score in frame: 0.1842
# Max score in frame: 0.1869
# Max score in frame: 0.1905
# Max score in frame: 0.1916
# Max score in frame: 0.1838
# Max score in frame: 0.1823
# Max score in frame: 0.1821
# Max score in frame: 0.1772
# Max score in frame: 0.1820
# Max score in frame: 0.1857
# Max score in frame: 0.1832
# Max score in frame: 0.1848
# Max score in frame: 0.1887
# Max score in frame: 0.1840
# Max score in frame: 0.1849
# Max score in frame: 0.1848
# Max score in frame: 0.2349
# Max score in frame: 0.4134
# Max score in frame: 0.1851
# Max score in frame: 0.2330
# Max score in frame: 0.1879
# Max score in frame: 0.1794
# Max score in frame: 0.1826
# Max score in frame: 0.1734
# Max score in frame: 0.1485
# Max score in frame: 0.1869
# Max score in frame: 0.1846
# Max score in frame: 0.1832
# Max score in frame: 0.1821
# Max score in frame: 0.1809
# Max score in frame: 0.1829
# Max score in frame: 0.1808
# Max score in frame: 0.1836
# Max score in frame: 0.1810
# Max score in frame: 0.1780
# Max score in frame: 0.1864
# Max score in frame: 0.1847
# Max score in frame: 0.1814
# Max score in frame: 0.1882
# Max score in frame: 0.1910
# Max score in frame: 0.1913
# Max score in frame: 0.4277
# Max score in frame: 0.1932
# Max score in frame: 0.1920
# Max score in frame: 0.4325
# Max score in frame: 0.1793
# Max score in frame: 0.1839
# Max score in frame: 0.1840
# Max score in frame: 0.1857
# Max score in frame: 0.4311
# Max score in frame: 0.1850
# Max score in frame: 0.1838
# Max score in frame: 0.1747
# Max score in frame: 0.1819
# Max score in frame: 0.1847
# Max score in frame: 0.1805
# Max score in frame: 0.1802
# Max score in frame: 0.1834
# Max score in frame: 0.1846
# Max score in frame: 0.1872
# Max score in frame: 0.1880
# Max score in frame: 0.1881
# Max score in frame: 0.1818
# Max score in frame: 0.1875
# Max score in frame: 0.1868
# Max score in frame: 0.1810
# Max score in frame: 0.1876
# Max score in frame: 0.1835
# Max score in frame: 0.1789
# Max score in frame: 0.1843
# Max score in frame: 0.1853
# Max score in frame: 0.1853
# Max score in frame: 0.1868
# Max score in frame: 0.1829
# Max score in frame: 0.1739
# Max score in frame: 0.1779
# Max score in frame: 0.1741
# Max score in frame: 0.1746
# Max score in frame: 0.1819
# Max score in frame: 0.1702
# Max score in frame: 0.1869
# Max score in frame: 0.1813
# Max score in frame: 0.1871
# Max score in frame: 0.1838
# Max score in frame: 0.1858
# Max score in frame: 0.1813
# Max score in frame: 0.1534
# Max score in frame: 0.1538
# Max score in frame: 0.1475
# Max score in frame: 0.1428
# Max score in frame: 0.1528
# Max score in frame: 0.1494
# Max score in frame: 0.1475
# Max score in frame: 0.1516
# Max score in frame: 0.1532
# Max score in frame: 0.3985
# Max score in frame: 0.3957
# Max score in frame: 0.1565
# Max score in frame: 0.1563
# Max score in frame: 0.4265
# Max score in frame: 0.4219
# Max score in frame: 0.4112
# Max score in frame: 0.4322
# Max score in frame: 0.4510
# Max score in frame: 0.4413
# Max score in frame: 0.4512
# Max score in frame: 0.4549
# Max score in frame: 0.4418
# Max score in frame: 0.4335
# Max score in frame: 0.4401
# Max score in frame: 0.4579
# Max score in frame: 0.4462
# Max score in frame: 0.4570
# Max score in frame: 0.4414
# Max score in frame: 0.4487
# Max score in frame: 0.1709
# Max score in frame: 0.1702
# Max score in frame: 0.4282
# Max score in frame: 0.4223
# Max score in frame: 0.4159
# Max score in frame: 0.4156
# Max score in frame: 0.4184
# Max score in frame: 0.4234
# Max score in frame: 0.4058
# Max score in frame: 0.4093
# Max score in frame: 0.4116
# Max score in frame: 0.4094
# Max score in frame: 0.4123
# Max score in frame: 0.4174
# Max score in frame: 0.4262
# Max score in frame: 0.4220
# Max score in frame: 0.4345
# Max score in frame: 0.4253
# Max score in frame: 0.4290
# Max score in frame: 0.4409
# Max score in frame: 0.4413
# Max score in frame: 0.4348
# Max score in frame: 0.4386
# Max score in frame: 0.4305
# Max score in frame: 0.4290
# Max score in frame: 0.4293
# Max score in frame: 0.1617
# Max score in frame: 0.1901
# Max score in frame: 0.1429
# Max score in frame: 0.2278
# Max score in frame: 0.1401
# Max score in frame: 0.2485
# Max score in frame: 0.1251
# Max score in frame: 0.1244
# Max score in frame: 0.1315
# Max score in frame: 0.3845
# Max score in frame: 0.1318
# Max score in frame: 0.3796
# Max score in frame: 0.1303
# Max score in frame: 0.3775
# Max score in frame: 0.3783
# Max score in frame: 0.3840
# Max score in frame: 0.3961
# Max score in frame: 0.3919
# Max score in frame: 0.3829
# Max score in frame: 0.3902
# Max score in frame: 0.3873
# Max score in frame: 0.4065
# Max score in frame: 0.4122
# Max score in frame: 0.1890
# Max score in frame: 0.4050
# Max score in frame: 0.4129
# Max score in frame: 0.4057
# Max score in frame: 0.4202
# Max score in frame: 0.4186
# Max score in frame: 0.4262
# Max score in frame: 0.4379
# Max score in frame: 0.4264
# Max score in frame: 0.1683
# Max score in frame: 0.4340
# Max score in frame: 0.4568
# Max score in frame: 0.4342
# Max score in frame: 0.4489
# Max score in frame: 0.4612
# Max score in frame: 0.4677
# Max score in frame: 0.4660
# Max score in frame: 0.4516
# Max score in frame: 0.4458
# Max score in frame: 0.4519
# Max score in frame: 0.4613
# Max score in frame: 0.4443
# Max score in frame: 0.4464
# Max score in frame: 0.4609
# Max score in frame: 0.1773
# Max score in frame: 0.2113
# Max score in frame: 0.4510
# Max score in frame: 0.2244
# Max score in frame: 0.2303
# Max score in frame: 0.2384
# Max score in frame: 0.4199
# Max score in frame: 0.4227
# Max score in frame: 0.4152
# Max score in frame: 0.4097
# Max score in frame: 0.4236
# Max score in frame: 0.4212
# Max score in frame: 0.4184
# Max score in frame: 0.4200
# Max score in frame: 0.5400
# Max score in frame: 0.4191
# Max score in frame: 0.4352
# Max score in frame: 0.4174
# Max score in frame: 0.4256
# Max score in frame: 0.1758
# Max score in frame: 0.4398
# Max score in frame: 0.2879
# Max score in frame: 0.2675
# Max score in frame: 0.1836
# Max score in frame: 0.4233
# Max score in frame: 0.1810
# Max score in frame: 0.4329
# Max score in frame: 0.4286
# Max score in frame: 0.4107
# Max score in frame: 0.4256
# Max score in frame: 0.4055
# Max score in frame: 0.4087
# Max score in frame: 0.4108
# Max score in frame: 0.3912
# Max score in frame: 0.3901
# Max score in frame: 0.3894
# Max score in frame: 0.3740
# Max score in frame: 0.3881
# Max score in frame: 0.3861
# Max score in frame: 0.3723
# Max score in frame: 0.3917
# Max score in frame: 0.3885
# Max score in frame: 0.3958
# Max score in frame: 0.3945
# Max score in frame: 0.3938
# Max score in frame: 0.3906
# Max score in frame: 0.4057
# Max score in frame: 0.4058
# Max score in frame: 0.3983
# Max score in frame: 0.4037
# Max score in frame: 0.3972
# Max score in frame: 0.3850
# Max score in frame: 0.3972
# Max score in frame: 0.3981
# Max score in frame: 0.4042
# Max score in frame: 0.3936
# Max score in frame: 0.3984
# Max score in frame: 0.3981
# Max score in frame: 0.4012
# Max score in frame: 0.3986
# Max score in frame: 0.4052
# Max score in frame: 0.3932
# Max score in frame: 0.3821
# Max score in frame: 0.1998
# Max score in frame: 0.2201
# Max score in frame: 0.2200
# Max score in frame: 0.4053
# Max score in frame: 0.4137
# Max score in frame: 0.3942
# Max score in frame: 0.3868
# Max score in frame: 0.4041
# Max score in frame: 0.4030
# Max score in frame: 0.1801
# Max score in frame: 0.3952
# Max score in frame: 0.3962
# Max score in frame: 0.4038
# Max score in frame: 0.4014
# Max score in frame: 0.3929
# Max score in frame: 0.2037
# Max score in frame: 0.3981
# Max score in frame: 0.3961
# Max score in frame: 0.3846
# Max score in frame: 0.1542
# Max score in frame: 0.3774
# Max score in frame: 0.3799
# Max score in frame: 0.1784
# Max score in frame: 0.1753
# Max score in frame: 0.3874
# Max score in frame: 0.1932
# Max score in frame: 0.3520
# Max score in frame: 0.3439
# Max score in frame: 0.3488
# Max score in frame: 0.0968
# Max score in frame: 0.0957
# Max score in frame: 0.0838
# Max score in frame: 0.0759
# Max score in frame: 0.2445
# Max score in frame: 0.2129
# Max score in frame: 0.1987
# Max score in frame: 0.0770
# Max score in frame: 0.3822
# Max score in frame: 0.4430
# Max score in frame: 0.5158
# Max score in frame: 0.4311
# Max score in frame: 0.4020
# Max score in frame: 0.3085
# Max score in frame: 0.3756
# Max score in frame: 0.4406
# Max score in frame: 0.3868
# Max score in frame: 0.4875
# Max score in frame: 0.4174
# Max score in frame: 0.3388
# Max score in frame: 0.4444
# Max score in frame: 0.1710
# Max score in frame: 0.3469
# Max score in frame: 0.2194
# Max score in frame: 0.3075
# Max score in frame: 0.4764
# Max score in frame: 0.5682
# Max score in frame: 0.7033
# Max score in frame: 0.6089
# Max score in frame: 0.6237
# Max score in frame: 0.7990
# Max score in frame: 0.8509
# Max score in frame: 0.8785
# Max score in frame: 0.8749
# Max score in frame: 0.6621
# Max score in frame: 0.9007
# Max score in frame: 0.9083
# Max score in frame: 0.9184
# Max score in frame: 0.9114
# Max score in frame: 0.8950
# Max score in frame: 0.9101
# Max score in frame: 0.9055
# Max score in frame: 0.9057
# Max score in frame: 0.9200
# Max score in frame: 0.9297
# Max score in frame: 0.9243
# Max score in frame: 0.9311
# Max score in frame: 0.9348
# Max score in frame: 0.9117
# Max score in frame: 0.8939
# Max score in frame: 0.9683
# Max score in frame: 0.8890
# Max score in frame: 0.9677
# Max score in frame: 0.9546
# Max score in frame: 0.9617
# Max score in frame: 0.9559
# Max score in frame: 0.9284
# Max score in frame: 0.9254
# Max score in frame: 0.9406
# Max score in frame: 0.9538
# Max score in frame: 0.9562
# Max score in frame: 0.9601
# Max score in frame: 0.9641
# Max score in frame: 0.9615
# Max score in frame: 0.9549
# Max score in frame: 0.9228
# Max score in frame: 0.9538
# Max score in frame: 0.9532
# Max score in frame: 0.9543
# Max score in frame: 0.9680
# Max score in frame: 0.9773
# Max score in frame: 0.9811
# Max score in frame: 0.9906
# Max score in frame: 0.9938
# Max score in frame: 0.9934
# Max score in frame: 0.9932
# Max score in frame: 0.9951
# Max score in frame: 0.9960
# Max score in frame: 0.9961
# Max score in frame: 0.9970
# Max score in frame: 0.9984
# Max score in frame: 0.9988
# Max score in frame: 0.9989
# Max score in frame: 0.9986
# Max score in frame: 0.9986
# Max score in frame: 0.9986
# Max score in frame: 0.9978
# Max score in frame: 0.9968
# Max score in frame: 0.9967
# Max score in frame: 0.9972
# Max score in frame: 0.9970
# Max score in frame: 0.9943
# Max score in frame: 0.9987
# Max score in frame: 0.9986
# Max score in frame: 0.9967
# Max score in frame: 0.9924
# Max score in frame: 0.9991
# Max score in frame: 0.9975
# Max score in frame: 0.9942
# Max score in frame: 0.9978
# Max score in frame: 0.9989
# Max score in frame: 0.9957
# Max score in frame: 0.9971
# Max score in frame: 0.9987
# Max score in frame: 0.9930
# Max score in frame: 0.9962
# Max score in frame: 0.9987
# Max score in frame: 0.9930
# Max score in frame: 0.9995
# Max score in frame: 0.9883
# Max score in frame: 0.9986
# Max score in frame: 0.9843
# Max score in frame: 0.9970
# Max score in frame: 0.9830
# Max score in frame: 0.9831
# Max score in frame: 0.9967
# Max score in frame: 0.9834
# Max score in frame: 0.9826
# Max score in frame: 0.9757
# Max score in frame: 0.9926
# Max score in frame: 0.9824
# Max score in frame: 0.9603
# Max score in frame: 0.9802
# Max score in frame: 0.9888
# Max score in frame: 0.9721
# Max score in frame: 0.9269
# Max score in frame: 0.9591
# Max score in frame: 0.9521
# Max score in frame: 0.9410
# Max score in frame: 0.9493
# Max score in frame: 0.9466
# Max score in frame: 0.8490
# Max score in frame: 0.9450
# Max score in frame: 0.9234
# Max score in frame: 0.7968
# Max score in frame: 0.9356
# Max score in frame: 0.9813
# Max score in frame: 0.9771
# Max score in frame: 0.9360
# Max score in frame: 0.9821
# Max score in frame: 0.9767
# Max score in frame: 0.8535
# Max score in frame: 0.9836
# Max score in frame: 0.9719
# Max score in frame: 0.9147
# Max score in frame: 0.9830
# Max score in frame: 0.9421
# Max score in frame: 0.9613
# Max score in frame: 0.9826
# Max score in frame: 0.9536
# Max score in frame: 0.9751
# Max score in frame: 0.9581
# Max score in frame: 0.9712
# Max score in frame: 0.9833
# Max score in frame: 0.9956
# Max score in frame: 0.9962
# Max score in frame: 0.9905
# Max score in frame: 0.9875
# Max score in frame: 0.9956
# Max score in frame: 0.9951
# Max score in frame: 0.9968
# Max score in frame: 0.9972
# Max score in frame: 0.9711
# Max score in frame: 0.9984
# Max score in frame: 0.9978
# Max score in frame: 0.9311
# Max score in frame: 0.9508
# Max score in frame: 0.9315
# Max score in frame: 0.9271
# Max score in frame: 0.9126
# Max score in frame: 0.9749
# Max score in frame: 0.8438
# Max score in frame: 0.8677
# Max score in frame: 0.9218
# Max score in frame: 0.7745
# Max score in frame: 0.7403
# Max score in frame: 0.6890
# Max score in frame: 0.6861
# Max score in frame: 0.7151
# Max score in frame: 0.9434
# Max score in frame: 0.8118
# Max score in frame: 0.5167
# Max score in frame: 0.7888
# Max score in frame: 0.3046
# Max score in frame: 0.2652
# Max score in frame: 0.2454
# Max score in frame: 0.2268
# Max score in frame: 0.1878
# Max score in frame: 0.1604
# Max score in frame: 0.4315
# Max score in frame: 0.4322
# Max score in frame: 0.1910
# Max score in frame: 0.1881
# Max score in frame: 0.4319
# Max score in frame: 0.4319
# Max score in frame: 0.4267
# Max score in frame: 0.4261
# Max score in frame: 0.4338
# Max score in frame: 0.1915
# Max score in frame: 0.1880
# Max score in frame: 0.4369
# Max score in frame: 0.4392
# Max score in frame: 0.4307
# Max score in frame: 0.4366
# Max score in frame: 0.4162
# Max score in frame: 0.4347
# Max score in frame: 0.4416
# Max score in frame: 0.4430
# Max score in frame: 0.1898
# Max score in frame: 0.1932
# Max score in frame: 0.1911
# Max score in frame: 0.1898
# Max score in frame: 0.1876
# Max score in frame: 0.1877
# Max score in frame: 0.4159
# Max score in frame: 0.1986
# Max score in frame: 0.1931
# Max score in frame: 0.4441
# Max score in frame: 0.4492
# Max score in frame: 0.4421
# Max score in frame: 0.4346
# Max score in frame: 0.4300
# Max score in frame: 0.4338
# Max score in frame: 0.4344
# Max score in frame: 0.4534
# Max score in frame: 0.4420
# Max score in frame: 0.4517
# Max score in frame: 0.4669
# Max score in frame: 0.4682
# Max score in frame: 0.4817
# Max score in frame: 0.1991
# Max score in frame: 0.4536
# Max score in frame: 0.2612
# Max score in frame: 0.1024
# Max score in frame: 0.0953
# Max score in frame: 0.1032
# Max score in frame: 0.6167
# Max score in frame: 0.4628
# Max score in frame: 0.4583
# Max score in frame: 0.6322
# Max score in frame: 0.5844
# Max score in frame: 0.2635
# Max score in frame: 0.3624
# Max score in frame: 0.4463
# Max score in frame: 0.5382
# Max score in frame: 0.3020
# Max score in frame: 0.3138
# Max score in frame: 0.4192
# Max score in frame: 0.3861
# Max score in frame: 0.3648
# Max score in frame: 0.4056
# Max score in frame: 0.9109
# Max score in frame: 0.9263
# Max score in frame: 0.6201
# Max score in frame: 0.5108
# Max score in frame: 0.5909
# Max score in frame: 0.6833
# Max score in frame: 0.7056
# Max score in frame: 0.7534
# Max score in frame: 0.7930
# Max score in frame: 0.7726
# Max score in frame: 0.7314
# Max score in frame: 0.7341
# Max score in frame: 0.9438
# Max score in frame: 0.9384
# Max score in frame: 0.6079
# Max score in frame: 0.5801
# Max score in frame: 0.5470
# Max score in frame: 0.5024
# Max score in frame: 0.5896
# Max score in frame: 0.9243
# Max score in frame: 0.9159
# Max score in frame: 0.9262
# Max score in frame: 0.9452
# Max score in frame: 0.7936
# Max score in frame: 0.9741
# Max score in frame: 0.9706
# Max score in frame: 0.9536
# Max score in frame: 0.9207
# Max score in frame: 0.9320
# Max score in frame: 0.9329
# Max score in frame: 0.9373
# Max score in frame: 0.9487
# Max score in frame: 0.9436
# Max score in frame: 0.9317
# Max score in frame: 0.9372
# Max score in frame: 0.8148
# Max score in frame: 0.7883
# Max score in frame: 0.7923
# Max score in frame: 0.8879
# Max score in frame: 0.8851
# Max score in frame: 0.9655
# Max score in frame: 0.8420
# Max score in frame: 0.7780
# Max score in frame: 0.7374
# Max score in frame: 0.7685
# Max score in frame: 0.5801
# Max score in frame: 0.4790
# Max score in frame: 0.6865
# Max score in frame: 0.4721
# Max score in frame: 0.4681
# Max score in frame: 0.5661
# Max score in frame: 0.5961
# Max score in frame: 0.7054
# Max score in frame: 0.6748
# Max score in frame: 0.6962
# Max score in frame: 0.8332
# Max score in frame: 0.9148
# Max score in frame: 0.9213
# Max score in frame: 0.8963
# Max score in frame: 0.9859
# Max score in frame: 0.9709
# Max score in frame: 0.9793
# Max score in frame: 0.9851
# Max score in frame: 0.9814
# Max score in frame: 0.9896
# Max score in frame: 0.9847
# Max score in frame: 0.9826
# Max score in frame: 0.9849
# Max score in frame: 0.9819
# Max score in frame: 0.9799
# Max score in frame: 0.9762
# Max score in frame: 0.9788
# Max score in frame: 0.9832
# Max score in frame: 0.9800
# Max score in frame: 0.9799
# Max score in frame: 0.9879
# Max score in frame: 0.9847
# Max score in frame: 0.9902
# Max score in frame: 0.9952
# Max score in frame: 0.9940
# Max score in frame: 0.9948
# Max score in frame: 0.9969
# Max score in frame: 0.9956
# Max score in frame: 0.9957
# Max score in frame: 0.9972
# Max score in frame: 0.9957
# Max score in frame: 0.9954
# Max score in frame: 0.9935
# Max score in frame: 0.9839
# Max score in frame: 0.9818
# Max score in frame: 0.9670
# Max score in frame: 0.9588
# Max score in frame: 0.9399
# Max score in frame: 0.9468
# Max score in frame: 0.9399
# Max score in frame: 0.9712
# Max score in frame: 0.9644
# Max score in frame: 0.9420
# Max score in frame: 0.9799
# Max score in frame: 0.9599
# Max score in frame: 0.9940
# Max score in frame: 0.9781
# Max score in frame: 0.9757
# Max score in frame: 0.9957
# Max score in frame: 0.9796
# Max score in frame: 0.9796
# Max score in frame: 0.9939
# Max score in frame: 0.9940
# Max score in frame: 0.9808
# Max score in frame: 0.9948
# Max score in frame: 0.9758
# Max score in frame: 0.9680
# Max score in frame: 0.9721
# Max score in frame: 0.9789
# Max score in frame: 0.9746
# Max score in frame: 0.9754
# Max score in frame: 0.9730
# Max score in frame: 0.9718
# Max score in frame: 0.9711
# Max score in frame: 0.9975
# Max score in frame: 0.9599
# Max score in frame: 0.9966
# Max score in frame: 0.9443
# Max score in frame: 0.9971
# Max score in frame: 0.9625
# Max score in frame: 0.9650
# Max score in frame: 0.9975
# Max score in frame: 0.9625
# Max score in frame: 0.9643
# Max score in frame: 0.9964
# Max score in frame: 0.9721
# Max score in frame: 0.9699
# Max score in frame: 0.9703
# Max score in frame: 0.9725
# Max score in frame: 0.9676
# Max score in frame: 0.9731
# Max score in frame: 0.9731
# Max score in frame: 0.9621
# Max score in frame: 0.9505
# Max score in frame: 0.9084
# Max score in frame: 0.8113
# Max score in frame: 0.9255
# Max score in frame: 0.5699
# Max score in frame: 0.6314
# Max score in frame: 0.7912
# Max score in frame: 0.9870
# Max score in frame: 0.5620
# Max score in frame: 0.6232
# Max score in frame: 0.7045
# Max score in frame: 0.7458
# Max score in frame: 0.6745
# Max score in frame: 0.7015
# Max score in frame: 0.6999
# Max score in frame: 0.6843
# Max score in frame: 0.5807
# Max score in frame: 0.5369
# Max score in frame: 0.5248
# Max score in frame: 0.5026
# Max score in frame: 0.4651
# Max score in frame: 0.4396
# Max score in frame: 0.3388
# Max score in frame: 0.2314
# Max score in frame: 0.2261
# Max score in frame: 0.2080
# Max score in frame: 0.1724
# Max score in frame: 0.3678
# Max score in frame: 0.3700
# Max score in frame: 0.3512
# Max score in frame: 0.2945
# Max score in frame: 0.6481
# Max score in frame: 0.5600
# Max score in frame: 0.4876
# Max score in frame: 0.4179
# Max score in frame: 0.3660
# Max score in frame: 0.1878
# Max score in frame: 0.1746
# Max score in frame: 0.1200
# Max score in frame: 0.4512
# Max score in frame: 0.4867
# Max score in frame: 0.1599
# Max score in frame: 0.1741
# Max score in frame: 0.2069
# Max score in frame: 0.2063
# Max score in frame: 0.4703
# Max score in frame: 0.4609
# Max score in frame: 0.1982
# Max score in frame: 0.1803
# Max score in frame: 0.1912
# Max score in frame: 0.4388
# Max score in frame: 0.2313
# Max score in frame: 0.2708
# Max score in frame: 0.3409
# Max score in frame: 0.6340
# Max score in frame: 0.6328
# Max score in frame: 0.4057
# Max score in frame: 0.5316
# Max score in frame: 0.4185
# Max score in frame: 0.6369
# Max score in frame: 0.6458
# Max score in frame: 0.6328
# Max score in frame: 0.6888
# Max score in frame: 0.6899
# Max score in frame: 0.6374
# Max score in frame: 0.7178
# Max score in frame: 0.6455
# Max score in frame: 0.4712
# Max score in frame: 0.2638
# Max score in frame: 0.4453
# Max score in frame: 0.3008
# Max score in frame: 0.2369
# Max score in frame: 0.2713
# Max score in frame: 0.2915
# Max score in frame: 0.3170
# Max score in frame: 0.2766
# Max score in frame: 0.4160
# Max score in frame: 0.2277
# Max score in frame: 0.2748
# Max score in frame: 0.2699
# Max score in frame: 0.4057
# Max score in frame: 0.3016
# Max score in frame: 0.5727
# Max score in frame: 0.6328
# Max score in frame: 0.6192
# Max score in frame: 0.7437
# Max score in frame: 0.8258
# Max score in frame: 0.7881
# Max score in frame: 0.7380
# Max score in frame: 0.7056
# Max score in frame: 0.6432
# ...
# Max score in frame: 0.4170
# Max score in frame: 0.4039
# Max score in frame: 0.1861
# Max score in frame: 0.1594
# Max score in frame: 0.4069
# Max score in frame: 0.3989
# Max score in frame: 0.4157
# Max score in frame: 0.1595
# Max score in frame: 0.1630
# Max score in frame: 0.2015
# Max score in frame: 0.1601
# Max score in frame: 0.2024
# Max score in frame: 0.1590
# Max score in frame: 0.1791
# Max score in frame: 0.1766
# Max score in frame: 0.1745
# Max score in frame: 0.1875
# Max score in frame: 0.1469
# Max score in frame: 0.1968
# Max score in frame: 0.5209
# Max score in frame: 0.1468
# Max score in frame: 0.2250
# Max score in frame: 0.1872
# Max score in frame: 0.1835
# Max score in frame: 0.2043
# Max score in frame: 0.2427
# Max score in frame: 0.6000
# Max score in frame: 0.2715
# Max score in frame: 0.2642
# Max score in frame: 0.6868
# Max score in frame: 0.2055
# Max score in frame: 0.3088
# Max score in frame: 0.7003
# Max score in frame: 0.6084
# Max score in frame: 0.1824
# Max score in frame: 0.3520
# Max score in frame: 0.2742
# Max score in frame: 0.7398
# Max score in frame: 0.4969
# Max score in frame: 0.7256
# Max score in frame: 0.8765
# Max score in frame: 0.8454
# Max score in frame: 0.9098
# Max score in frame: 0.8856
# Max score in frame: 0.8473
# Max score in frame: 0.9228
# Max score in frame: 0.9812
# Max score in frame: 0.9083
# Max score in frame: 0.8875
# Max score in frame: 0.9591
# Max score in frame: 0.9231
# Max score in frame: 0.9177
# Max score in frame: 0.8752
# Max score in frame: 0.9079
# Max score in frame: 0.8241
# Max score in frame: 0.8783
# Max score in frame: 0.8302
# Max score in frame: 0.8106
# Max score in frame: 0.8003
# Max score in frame: 0.8585
# Max score in frame: 0.8277
# Max score in frame: 0.8465
# Max score in frame: 0.9156
# Max score in frame: 0.8536
# Max score in frame: 0.8596
# Max score in frame: 0.8500
# Max score in frame: 0.8796
# Max score in frame: 0.8152
# Max score in frame: 0.7631
# Max score in frame: 0.8949
# Max score in frame: 0.8804
# Max score in frame: 0.8366
# Max score in frame: 0.8702
# Max score in frame: 0.5637
# Max score in frame: 0.6207
# Max score in frame: 0.8023
# Max score in frame: 0.4785
# Max score in frame: 0.6333
# Max score in frame: 0.7218
# Max score in frame: 0.5370
# Max score in frame: 0.8386
# Max score in frame: 0.7244
# Max score in frame: 0.7133
# Max score in frame: 0.8014
# Max score in frame: 0.7141
# Max score in frame: 0.7856
# Max score in frame: 0.8312
# Max score in frame: 0.7187
# Max score in frame: 0.7738
# Max score in frame: 0.8592
# Max score in frame: 0.6278
# Max score in frame: 0.7071
# Max score in frame: 0.8857
# Max score in frame: 0.6447
# Max score in frame: 0.7125
# Max score in frame: 0.7655
# Max score in frame: 0.7684
# Max score in frame: 0.9679
# Max score in frame: 0.7369
# Max score in frame: 0.8683
# Max score in frame: 0.8995
# Max score in frame: 0.8557
# Max score in frame: 0.9277
# Max score in frame: 0.9471
# Max score in frame: 0.9208
# Max score in frame: 0.9492
# Max score in frame: 0.9501
# Max score in frame: 0.9713
# Max score in frame: 0.9772
# Max score in frame: 0.9828
# Max score in frame: 0.9837
# Max score in frame: 0.9849
# Max score in frame: 0.9897
# Max score in frame: 0.9943
# Max score in frame: 0.9945
# Max score in frame: 0.9967
# Max score in frame: 0.9997
# Max score in frame: 0.9980
# Max score in frame: 0.9998
# Max score in frame: 0.9998
# Max score in frame: 0.9978
# Max score in frame: 0.9990
# Max score in frame: 0.9991
# Max score in frame: 0.9982
# Max score in frame: 0.9998
# Max score in frame: 0.9991
# Max score in frame: 0.9994
# Max score in frame: 0.9997
# Max score in frame: 0.9990
# Max score in frame: 0.9998
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9999
# Max score in frame: 0.9998
# Max score in frame: 0.9998
# Max score in frame: 0.9997
# Max score in frame: 0.9996
# Max score in frame: 0.9997
# Max score in frame: 0.9996
# Max score in frame: 0.9980
# Max score in frame: 0.9968
# Max score in frame: 0.9993
# Max score in frame: 0.9972
# Max score in frame: 0.9966
# Max score in frame: 0.9993
# Max score in frame: 0.9967
# Max score in frame: 0.9993
# Max score in frame: 0.9993
# Max score in frame: 0.9935
# Max score in frame: 0.9890
# Max score in frame: 0.9897
# Max score in frame: 0.9846
# Max score in frame: 0.9738
# Max score in frame: 0.9729
# Max score in frame: 0.9694
# Max score in frame: 0.9653
# Max score in frame: 0.9722
# Max score in frame: 0.9670
# Max score in frame: 0.9688
# Max score in frame: 0.9662
# Max score in frame: 0.9686
# Max score in frame: 0.9696
# Max score in frame: 0.9690
# Max score in frame: 0.9104
# Max score in frame: 0.9723
# Max score in frame: 0.9589
# Max score in frame: 0.9823
# Max score in frame: 0.9942
# Max score in frame: 0.9346
# Max score in frame: 0.9816
# Max score in frame: 0.9963
# Max score in frame: 0.9905
# Max score in frame: 0.9931
# Max score in frame: 0.9871
# Max score in frame: 0.9778
# Max score in frame: 0.9762
# Max score in frame: 0.8153
# Max score in frame: 0.6817
# Max score in frame: 0.8333
# Max score in frame: 0.7230
# Max score in frame: 0.5891
# Max score in frame: 0.8435
# Max score in frame: 0.6448
# Max score in frame: 0.8247
# Max score in frame: 0.6957
# Max score in frame: 0.6508
# Max score in frame: 0.5116
# Max score in frame: 0.2913
# Max score in frame: 0.3000
# Max score in frame: 0.7099
# Max score in frame: 0.5514
# Max score in frame: 0.4482
# Max score in frame: 0.7692
# Max score in frame: 0.2111
# Max score in frame: 0.5266
# Max score in frame: 0.1941
# Max score in frame: 0.6503
# Max score in frame: 0.6112
# Max score in frame: 0.7530
# Max score in frame: 0.5992
# Max score in frame: 0.6655
# Max score in frame: 0.6212
# Max score in frame: 0.5907
# Max score in frame: 0.5897
# Max score in frame: 0.6472
# Max score in frame: 0.6527
# Max score in frame: 0.6494
# Max score in frame: 0.6411
# Max score in frame: 0.6590
# Max score in frame: 0.5542
# Max score in frame: 0.5400
# Max score in frame: 0.5267
# Max score in frame: 0.7146
# Max score in frame: 0.5276
# Max score in frame: 0.5190
# Max score in frame: 0.6765
# Max score in frame: 0.6855
# Max score in frame: 0.7027
# Max score in frame: 0.6945
# Max score in frame: 0.6911
# Max score in frame: 0.6863
# Max score in frame: 0.6892
# Max score in frame: 0.6467
# Max score in frame: 0.6571
# Max score in frame: 0.7982
# Max score in frame: 0.8102
# Max score in frame: 0.8465
# Max score in frame: 0.7325
# Max score in frame: 0.6541
# Max score in frame: 0.5549
# Max score in frame: 0.6943
# Max score in frame: 0.7134
# Max score in frame: 0.5155
# Max score in frame: 0.5441
# Max score in frame: 0.7709
# Max score in frame: 0.7567
# Max score in frame: 0.7676
# Max score in frame: 0.5874
# Max score in frame: 0.8235
# Max score in frame: 0.7051
# Max score in frame: 0.7186
# Max score in frame: 0.7736
# Max score in frame: 0.8030
# Max score in frame: 0.8472
# Max score in frame: 0.8907
# Max score in frame: 0.9114
# Max score in frame: 0.9288
# Max score in frame: 0.9318
# Max score in frame: 0.9366
# Max score in frame: 0.9347
# Max score in frame: 0.9261
# Max score in frame: 0.9122
# Max score in frame: 0.9072
# Max score in frame: 0.8915
# Max score in frame: 0.8835
# Max score in frame: 0.8857
# Max score in frame: 0.8296
# Max score in frame: 0.8828
# Max score in frame: 0.8987
# Max score in frame: 0.9046
# Max score in frame: 0.9044
# Max score in frame: 0.9053
# Max score in frame: 0.7642
# Max score in frame: 0.9165
# Max score in frame: 0.9325
# Max score in frame: 0.9333
# Max score in frame: 0.9242
# Max score in frame: 0.9220
# Max score in frame: 0.9315
# Max score in frame: 0.9659
# Max score in frame: 0.9586
# Max score in frame: 0.9438
# Max score in frame: 0.9665
# Max score in frame: 0.9706
# Max score in frame: 0.9580
# Max score in frame: 0.9565
# Max score in frame: 0.9777
# Max score in frame: 0.9489
# Max score in frame: 0.9829
# Max score in frame: 0.9863
# Max score in frame: 0.9898
# Max score in frame: 0.9904
# Max score in frame: 0.9910
# Max score in frame: 0.9907
# Max score in frame: 0.9882
# Max score in frame: 0.9327
# Max score in frame: 0.9291
# Max score in frame: 0.9259
# Max score in frame: 0.9187
# Max score in frame: 0.9120
# Max score in frame: 0.9031
# Max score in frame: 0.8771
# Max score in frame: 0.9290
# Max score in frame: 0.9396
# Max score in frame: 0.9139
# Max score in frame: 0.9248
# Max score in frame: 0.9867
# Max score in frame: 0.9070
# Max score in frame: 0.9250
# Max score in frame: 0.9424
# Max score in frame: 0.9214
# Max score in frame: 0.9078
# Max score in frame: 0.9886
# Max score in frame: 0.9875
# Max score in frame: 0.9838
# Max score in frame: 0.9819
# Max score in frame: 0.9805
# Max score in frame: 0.9765
# Max score in frame: 0.9766
# Max score in frame: 0.9798
# Max score in frame: 0.9809
# Max score in frame: 0.9807
# Max score in frame: 0.9307
# Max score in frame: 0.9755
# Max score in frame: 0.8810
# Max score in frame: 0.9222
# Max score in frame: 0.9847
# Max score in frame: 0.9857
# Max score in frame: 0.9874
# Max score in frame: 0.9847
# Max score in frame: 0.9898
# Max score in frame: 0.9751
# Max score in frame: 0.9877
# Max score in frame: 0.9873
# Max score in frame: 0.9661
# Max score in frame: 0.8231
# Max score in frame: 0.9102
# Max score in frame: 0.9193
# Max score in frame: 0.8685
# Max score in frame: 0.4245
# Max score in frame: 0.6518
# Max score in frame: 0.8300
# Max score in frame: 0.2931
# Max score in frame: 0.5064
# Max score in frame: 0.8302
# Max score in frame: 0.4419
# Max score in frame: 0.8571
# Max score in frame: 0.6116
# Max score in frame: 0.8624
# Max score in frame: 0.8566
# Max score in frame: 0.7410
# Max score in frame: 0.8684
# Max score in frame: 0.5213
# Max score in frame: 0.5277
# Max score in frame: 0.7836
# Max score in frame: 0.8496
# Max score in frame: 0.8648
# Max score in frame: 0.9464
# Max score in frame: 0.9543
# Max score in frame: 0.9825
# Max score in frame: 0.9847
# Max score in frame: 0.9614
# Max score in frame: 0.9627
# Max score in frame: 0.9647
# Max score in frame: 0.9938
# Max score in frame: 0.9977
# Max score in frame: 0.9951
# Max score in frame: 0.9939
# Max score in frame: 0.9916
# Max score in frame: 0.9960
# Max score in frame: 0.9833
# Max score in frame: 0.9976
# Max score in frame: 0.9936
# Max score in frame: 0.9889
# Max score in frame: 0.9870
# Max score in frame: 0.9950
# Max score in frame: 0.9912
# Max score in frame: 0.9870
# Max score in frame: 0.9899
# Max score in frame: 0.9863
# Max score in frame: 0.9839
# Max score in frame: 0.9967
# Max score in frame: 0.9947
# Max score in frame: 0.9838
# Max score in frame: 0.9964
# Max score in frame: 0.9899
# Max score in frame: 0.9811
# Max score in frame: 0.9953
# Max score in frame: 0.9757
# Max score in frame: 0.9730
# Max score in frame: 0.9947
# Max score in frame: 0.9859
# Max score in frame: 0.9902
# Max score in frame: 0.9942
# Max score in frame: 0.9830
# Max score in frame: 0.9915
# Max score in frame: 0.9782
# Max score in frame: 0.9948
# Max score in frame: 0.9911
# Max score in frame: 0.9812
# Max score in frame: 0.9946
# Max score in frame: 0.9937
# Max score in frame: 0.9943
# Max score in frame: 0.9946
# Max score in frame: 0.9884
# Max score in frame: 0.9668
# Max score in frame: 0.9932
# Max score in frame: 0.9886
# Max score in frame: 0.9808
# Max score in frame: 0.9958
# Max score in frame: 0.9919
# Max score in frame: 0.9857
# Max score in frame: 0.9921
# Max score in frame: 0.9882
# Max score in frame: 0.9891
# Max score in frame: 0.9945
# Max score in frame: 0.9779
# Max score in frame: 0.9937
# Max score in frame: 0.9945
# Max score in frame: 0.9910
# Max score in frame: 0.9929
# Max score in frame: 0.9778
# Max score in frame: 0.9925
# Max score in frame: 0.9849
# Max score in frame: 0.9881
# Max score in frame: 0.9931
# Max score in frame: 0.9812
# Max score in frame: 0.9878
# Max score in frame: 0.9888
# Max score in frame: 0.9833
# Max score in frame: 0.9570
# Max score in frame: 0.9839
# Max score in frame: 0.9920
# Max score in frame: 0.9897
# Max score in frame: 0.9948
# Max score in frame: 0.9830
# Max score in frame: 0.9820
# Max score in frame: 0.9920
# Max score in frame: 0.9927
# Max score in frame: 0.9770
# Max score in frame: 0.9910
# Max score in frame: 0.9837
# Max score in frame: 0.9928
# Max score in frame: 0.9923
# Max score in frame: 0.9937
# Max score in frame: 0.9929
# Max score in frame: 0.9866
# Max score in frame: 0.9936
# Max score in frame: 0.9770
# Max score in frame: 0.9761
# Max score in frame: 0.9921
# Max score in frame: 0.9734
# Max score in frame: 0.9799
# Max score in frame: 0.9714
# Max score in frame: 0.9690
# Max score in frame: 0.9483
# Max score in frame: 0.8776
# Max score in frame: 0.8783
# Max score in frame: 0.7312
# Max score in frame: 0.8682
# Max score in frame: 0.7358
# Max score in frame: 0.8285
# Max score in frame: 0.8426
# Max score in frame: 0.8342
# Max score in frame: 0.9068
# Max score in frame: 0.9617
# Max score in frame: 0.9630
# Max score in frame: 0.9610
# Max score in frame: 0.8620
# Max score in frame: 0.9053
# Max score in frame: 0.9075
# Max score in frame: 0.9427
# Max score in frame: 0.9022
# Max score in frame: 0.8597
# Max score in frame: 0.8618
# Max score in frame: 0.8886
# Max score in frame: 0.6487
# Max score in frame: 0.8030
# Max score in frame: 0.8438
# Max score in frame: 0.9160
# Max score in frame: 0.7201
# Max score in frame: 0.9328
# Max score in frame: 0.9353
# Max score in frame: 0.8795
# Max score in frame: 0.8817
# Max score in frame: 0.9753
# Max score in frame: 0.8600
# Max score in frame: 0.9275
# Max score in frame: 0.9300
# Max score in frame: 0.8991
# Max score in frame: 0.9008
# Max score in frame: 0.9351
# Max score in frame: 0.9167
# Max score in frame: 0.9181
# Max score in frame: 0.9432
# Max score in frame: 0.9438
# Max score in frame: 0.9601
# Max score in frame: 0.9684
# Max score in frame: 0.9636
# Max score in frame: 0.9705
# Max score in frame: 0.9802
# Max score in frame: 0.9832
# Max score in frame: 0.9859
# Max score in frame: 0.9846
# Max score in frame: 0.9817
# Max score in frame: 0.9833
# Max score in frame: 0.9875
# Max score in frame: 0.9859
# Max score in frame: 0.9864
# Max score in frame: 0.9894
# Max score in frame: 0.9923
# Max score in frame: 0.9920
# Max score in frame: 0.9984
# Max score in frame: 0.9979
# Max score in frame: 0.9983
# Max score in frame: 0.9987
# Max score in frame: 0.9985
# Max score in frame: 0.9989
# Max score in frame: 0.9991
# Max score in frame: 0.9992
# Max score in frame: 0.9994
# Max score in frame: 0.9992
# Max score in frame: 0.9964
# Max score in frame: 0.9961
# Max score in frame: 0.9950
# Max score in frame: 0.9955
# Max score in frame: 0.9943
# Max score in frame: 0.9892
# Max score in frame: 0.9901
# Max score in frame: 0.9894
# Max score in frame: 0.9783
# Max score in frame: 0.9730
# Max score in frame: 0.9714
# Max score in frame: 0.9910
# Max score in frame: 0.9942
# Max score in frame: 0.9769
# Max score in frame: 0.9934
# Max score in frame: 0.9939
# Max score in frame: 0.9913
# Max score in frame: 0.9894
# Max score in frame: 0.9865
# Max score in frame: 0.9843
# Max score in frame: 0.9866
# Max score in frame: 0.9787
# Max score in frame: 0.9817
# Max score in frame: 0.9760
# Max score in frame: 0.9660
# Max score in frame: 0.9620
# Max score in frame: 0.9710
# Max score in frame: 0.8889
# Max score in frame: 0.8687
# Max score in frame: 0.9349
# Max score in frame: 0.9532
# Max score in frame: 0.9274
# Max score in frame: 0.7845
# Max score in frame: 0.8920
# Max score in frame: 0.8552
# Max score in frame: 0.8315
# Max score in frame: 0.7698
# Max score in frame: 0.7871
# Max score in frame: 0.7968
# Max score in frame: 0.7971
# Max score in frame: 0.7625
# Max score in frame: 0.7663
# Max score in frame: 0.6561
# Max score in frame: 0.6290
# Max score in frame: 0.6142
# Max score in frame: 0.6001
# Max score in frame: 0.6470
# Max score in frame: 0.5586
# Max score in frame: 0.6326
# Max score in frame: 0.5760
# Max score in frame: 0.5128
# Max score in frame: 0.3763
# Max score in frame: 0.4195
# Max score in frame: 0.4462
# Max score in frame: 0.4354
# Max score in frame: 0.4484
# Max score in frame: 0.4399
# Max score in frame: 0.4326
# Max score in frame: 0.4247
# Max score in frame: 0.2387
# Max score in frame: 0.4065
# Max score in frame: 0.3942
# Max score in frame: 0.4372
# Max score in frame: 0.4465
# Max score in frame: 0.4473
# Max score in frame: 0.4367
# Max score in frame: 0.4562
# Max score in frame: 0.4809
# Max score in frame: 0.4856
# Max score in frame: 0.4806
# Max score in frame: 0.5225
# Max score in frame: 0.4696
# Max score in frame: 0.4870
# Max score in frame: 0.2305
# Max score in frame: 0.5025
# Video saved to output_demo.avi
# Finished: Saved to processed_fruit-and-vegetable-detection.avi

# %%
# Convert all processed videos to mp4
# !for f in processed_*.avi; do ffmpeg -y -i "$f" -vcodec libx264 -crf 25 "${f%.avi}.mp4"; done
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from 'processed_car-detection.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:31.42, start: 0.000000, bitrate: 1173 kb/s
#   Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 768x432, 1172 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5bfa17510600] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5bfa17510600] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x5bfa17510600] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=12 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=25.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'processed_car-detection.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/unknown/unknown, progressive), 768x432, q=2-31, 12 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  377 fps= 43 q=-1.0 Lsize=    1310kB time=00:00:31.16 bitrate= 344.3kbits/s speed= 3.6x
# video:1305kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.362252%
# [libx264 @ 0x5bfa17510600] frame I:3     Avg QP:17.66  size:  8209
# [libx264 @ 0x5bfa17510600] frame P:167   Avg QP:20.29  size:  5127
# [libx264 @ 0x5bfa17510600] frame B:207   Avg QP:21.00  size:  2199
# [libx264 @ 0x5bfa17510600] consecutive B-frames: 22.8% 10.6%  4.0% 62.6%
# [libx264 @ 0x5bfa17510600] mb I  I16..4: 20.8% 76.9%  2.4%
# [libx264 @ 0x5bfa17510600] mb P  I16..4: 12.7% 41.9%  1.5%  P16..4: 15.5%  5.5%  2.5%  0.0%  0.0%    skip:20.5%
# [libx264 @ 0x5bfa17510600] mb B  I16..4:  4.1% 17.2%  0.1%  B16..8: 29.7%  3.7%  0.4%  direct: 1.8%  skip:43.1%  L0:52.1% L1:43.2% BI: 4.7%
# [libx264 @ 0x5bfa17510600] 8x8 transform intra:76.6% inter:87.3%
# [libx264 @ 0x5bfa17510600] coded y,uvDC,uvAC intra: 39.8% 20.2% 1.3% inter: 11.2% 13.1% 0.3%
# [libx264 @ 0x5bfa17510600] i16 v,h,dc,p: 30% 41% 22%  8%
# [libx264 @ 0x5bfa17510600] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 27% 41%  1%  0%  0%  0%  0%  1%
# [libx264 @ 0x5bfa17510600] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 32% 13%  2%  2%  3%  2%  2%  3%
# [libx264 @ 0x5bfa17510600] i8c dc,h,v,p: 62% 19% 18%  1%
# [libx264 @ 0x5bfa17510600] Weighted P-Frames: Y:31.7% UV:10.2%
# [libx264 @ 0x5bfa17510600] ref P L0: 54.1% 14.3% 23.0%  8.2%  0.4%
# [libx264 @ 0x5bfa17510600] ref B L0: 79.6% 16.0%  4.4%
# [libx264 @ 0x5bfa17510600] ref B L1: 91.8%  8.2%
# [libx264 @ 0x5bfa17510600] kb/s:340.19
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from 'processed_fruit-and-vegetable-detection.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:01:01.58, start: 0.000000, bitrate: 9133 kb/s
#   Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 960x540, 9122 kb/s, 59 fps, 59 tbr, 59 tbn, 59 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5a1bcd7202c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5a1bcd7202c0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5a1bcd7202c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=25.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'processed_fruit-and-vegetable-detection.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/unknown/unknown, progressive), 960x540, q=2-31, 59 fps, 15104 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 3633 fps= 56 q=-1.0 Lsize=    6260kB time=00:01:01.52 bitrate= 833.5kbits/s speed=0.948x
# video:6221kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.631133%
# [libx264 @ 0x5a1bcd7202c0] frame I:19    Avg QP:22.13  size:  6668
# [libx264 @ 0x5a1bcd7202c0] frame P:1516  Avg QP:24.72  size:  2686
# [libx264 @ 0x5a1bcd7202c0] frame B:2098  Avg QP:24.12  size:  1034
# [libx264 @ 0x5a1bcd7202c0] consecutive B-frames: 18.2% 11.8%  8.0% 62.0%
# [libx264 @ 0x5a1bcd7202c0] mb I  I16..4: 38.4% 58.9%  2.6%
# [libx264 @ 0x5a1bcd7202c0] mb P  I16..4: 12.5% 12.2%  0.6%  P16..4: 17.9%  1.8%  0.4%  0.0%  0.0%    skip:54.5%
# [libx264 @ 0x5a1bcd7202c0] mb B  I16..4:  1.6%  1.0%  0.0%  B16..8: 17.2%  1.1%  0.0%  direct: 3.9%  skip:75.2%  L0:46.9% L1:52.5% BI: 0.6%
# [libx264 @ 0x5a1bcd7202c0] 8x8 transform intra:47.6% inter:96.4%
# [libx264 @ 0x5a1bcd7202c0] coded y,uvDC,uvAC intra: 10.9% 33.4% 2.9% inter: 2.2% 8.5% 0.4%
# [libx264 @ 0x5a1bcd7202c0] i16 v,h,dc,p: 26% 59% 11%  5%
# [libx264 @ 0x5a1bcd7202c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 24% 54%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x5a1bcd7202c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 52% 16%  2%  2%  2%  3%  1%  2%
# [libx264 @ 0x5a1bcd7202c0] i8c dc,h,v,p: 48% 34% 18%  1%
# [libx264 @ 0x5a1bcd7202c0] Weighted P-Frames: Y:0.9% UV:0.1%
# [libx264 @ 0x5a1bcd7202c0] ref P L0: 50.1%  9.3% 28.1% 12.5%  0.1%
# [libx264 @ 0x5a1bcd7202c0] ref B L0: 70.2% 24.4%  5.3%
# [libx264 @ 0x5a1bcd7202c0] ref B L1: 91.0%  9.0%
# [libx264 @ 0x5a1bcd7202c0] kb/s:827.50
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from 'processed_one-by-one-person-detection.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:49.50, start: 0.000000, bitrate: 2947 kb/s
#   Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 768x432, 2950 kb/s, 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5948dd3c03c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5948dd3c03c0] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x5948dd3c03c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=25.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'processed_one-by-one-person-detection.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/unknown/unknown, progressive), 768x432, q=2-31, 10 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  495 fps= 55 q=-1.0 Lsize=    2387kB time=00:00:49.20 bitrate= 397.4kbits/s speed=5.43x
# video:2381kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.267874%
# [libx264 @ 0x5948dd3c03c0] frame I:3     Avg QP:20.05  size: 21664
# [libx264 @ 0x5948dd3c03c0] frame P:168   Avg QP:21.90  size:  9299
# [libx264 @ 0x5948dd3c03c0] frame B:324   Avg QP:26.19  size:  2500
# [libx264 @ 0x5948dd3c03c0] consecutive B-frames:  8.5%  8.5% 12.7% 70.3%
# [libx264 @ 0x5948dd3c03c0] mb I  I16..4: 22.2% 60.8% 17.0%
# [libx264 @ 0x5948dd3c03c0] mb P  I16..4:  7.0% 17.0%  5.7%  P16..4: 17.8%  8.9%  5.4%  0.0%  0.0%    skip:38.2%
# [libx264 @ 0x5948dd3c03c0] mb B  I16..4:  1.8%  2.2%  1.4%  B16..8: 21.0%  4.6%  0.8%  direct: 1.0%  skip:67.3%  L0:52.6% L1:43.8% BI: 3.7%
# [libx264 @ 0x5948dd3c03c0] 8x8 transform intra:53.3% inter:71.3%
# [libx264 @ 0x5948dd3c03c0] coded y,uvDC,uvAC intra: 47.3% 56.0% 22.0% inter: 7.7% 12.4% 5.1%
# [libx264 @ 0x5948dd3c03c0] i16 v,h,dc,p: 51% 35%  9%  6%
# [libx264 @ 0x5948dd3c03c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 19% 31%  3%  1%  3%  1%  4%  1%
# [libx264 @ 0x5948dd3c03c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 27% 12%  2%  2%  5%  2%  4%  2%
# [libx264 @ 0x5948dd3c03c0] i8c dc,h,v,p: 28% 36% 33%  3%
# [libx264 @ 0x5948dd3c03c0] Weighted P-Frames: Y:13.1% UV:0.6%
# [libx264 @ 0x5948dd3c03c0] ref P L0: 57.1% 13.9% 18.2% 10.1%  0.7%
# [libx264 @ 0x5948dd3c03c0] ref B L0: 74.4% 20.2%  5.4%
# [libx264 @ 0x5948dd3c03c0] ref B L1: 92.9%  7.1%
# [libx264 @ 0x5948dd3c03c0] kb/s:393.86
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from 'processed_person-bicycle-car-detection.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:53.92, start: 0.000000, bitrate: 1307 kb/s
#   Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 768x432, 1305 kb/s, 12 fps, 12 tbr, 12 tbn, 12 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5a0c63b7b280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5a0c63b7b280] profile High, level 2.2, 4:2:0, 8-bit
# [libx264 @ 0x5a0c63b7b280] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=12 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=25.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'processed_person-bicycle-car-detection.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/unknown/unknown, progressive), 768x432, q=2-31, 12 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  647 fps= 55 q=-1.0 Lsize=    1763kB time=00:00:53.66 bitrate= 269.1kbits/s speed=4.55x
# video:1754kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.473488%
# [libx264 @ 0x5a0c63b7b280] frame I:3     Avg QP:16.60  size: 12365
# [libx264 @ 0x5a0c63b7b280] frame P:188   Avg QP:18.79  size:  5456
# [libx264 @ 0x5a0c63b7b280] frame B:456   Avg QP:20.92  size:  1608
# [libx264 @ 0x5a0c63b7b280] consecutive B-frames:  3.6%  6.2%  3.7% 86.6%
# [libx264 @ 0x5a0c63b7b280] mb I  I16..4: 12.8% 85.9%  1.3%
# [libx264 @ 0x5a0c63b7b280] mb P  I16..4:  3.7% 36.5%  0.4%  P16..4: 18.4%  7.9%  5.3%  0.0%  0.0%    skip:27.8%
# [libx264 @ 0x5a0c63b7b280] mb B  I16..4:  1.1%  9.1%  0.0%  B16..8: 33.3%  4.7%  0.4%  direct: 2.0%  skip:49.5%  L0:53.2% L1:43.1% BI: 3.7%
# [libx264 @ 0x5a0c63b7b280] 8x8 transform intra:89.5% inter:83.6%
# [libx264 @ 0x5a0c63b7b280] coded y,uvDC,uvAC intra: 47.7% 17.7% 0.3% inter: 7.9% 8.5% 0.0%
# [libx264 @ 0x5a0c63b7b280] i16 v,h,dc,p: 22% 39% 32%  7%
# [libx264 @ 0x5a0c63b7b280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 27% 48%  1%  0%  0%  0%  0%  1%
# [libx264 @ 0x5a0c63b7b280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 29% 15%  4%  5%  6%  5%  4%  3%
# [libx264 @ 0x5a0c63b7b280] i8c dc,h,v,p: 68% 17% 15%  1%
# [libx264 @ 0x5a0c63b7b280] Weighted P-Frames: Y:5.3% UV:1.1%
# [libx264 @ 0x5a0c63b7b280] ref P L0: 52.8% 11.1% 24.5% 11.5%  0.1%
# [libx264 @ 0x5a0c63b7b280] ref B L0: 76.2% 18.3%  5.5%
# [libx264 @ 0x5a0c63b7b280] ref B L1: 91.3%  8.7%
# [libx264 @ 0x5a0c63b7b280] kb/s:266.45
